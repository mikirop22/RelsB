# %% [markdown]
# # Preprocessing

# %%
import pandas as pd

# read the data

df = pd.read_csv('train.csv')
df.describe()
# Out:
#        Characteristics.LotSizeSquareFeet  ImageData.c1c6.summary.bathroom  \
# count                       1.690000e+03                     90744.000000
# mean                        5.949145e+04                         3.116429
# std                         4.784652e+05                         0.724160
# min                         0.000000e+00                         1.000000
# 25%                         3.743750e+03                         2.800000
# 50%                         8.712000e+03                         3.200000
# 75%                         2.452075e+04                         3.600000
# max                         9.999999e+06                         6.000000
#
#        ImageData.c1c6.summary.exterior  ImageData.c1c6.summary.interior  \
# count                     87789.000000                     93597.000000
# mean                          3.308723                         3.211074
# std                           0.676499                         0.677497
# min                           1.000000                         1.000000
# 25%                           3.100000                         2.900000
# 50%                           3.400000                         3.300000
# 75%                           3.700000                         3.600000
# max                           6.000000                         6.000000
#
#        ImageData.c1c6.summary.kitchen  ImageData.c1c6.summary.property  \
# count                    92320.000000                    103055.000000
# mean                         3.117166                         3.182633
# std                          0.743597                         0.682011
# min                          1.000000                         1.000000
# 25%                          2.800000                         2.900000
# 50%                          3.200000                         3.200000
# 75%                          3.600000                         3.600000
# max                          6.000000                         6.000000
#
#        ImageData.q1q6.summary.bathroom  ImageData.q1q6.summary.exterior  \
# count                     90708.000000                     82565.000000
# mean                          3.311895                         3.499023
# std                           0.508110                         0.594215
# min                           1.000000                         1.000000
# 25%                           3.000000                         3.100000
# 50%                           3.300000                         3.500000
# 75%                           3.700000                         3.900000
# max                           5.100000                         5.400000
#
#        ImageData.q1q6.summary.interior  ImageData.q1q6.summary.kitchen  ...  \
# count                     93589.000000                    92292.000000  ...
# mean                          3.108145                        3.209570  ...
# std                           0.540139                        0.645833  ...
# min                           1.000000                        1.000000  ...
# 25%                           2.800000                        2.800000  ...
# 50%                           3.000000                        3.200000  ...
# 75%                           3.400000                        3.800000  ...
# max                           5.100000                        5.000000  ...
#
#        Structure.BathroomsFull  Structure.BathroomsHalf  \
# count            100063.000000            100049.000000
# mean                  1.921669                 0.441973
# std                   0.864013                 0.548588
# min                   0.000000                 0.000000
# 25%                   1.000000                 0.000000
# 50%                   2.000000                 0.000000
# 75%                   2.000000                 1.000000
# max                  75.000000                 9.000000
#
#        Structure.BedroomsTotal  Structure.BelowGradeFinishedArea  \
# count            105024.000000                      14235.000000
# mean                  3.102167                        701.495539
# std                   1.235208                        635.400209
# min                   0.000000                          0.000000
# 25%                   2.000000                          0.000000
# 50%                   3.000000                        696.000000
# 75%                   4.000000                       1073.000000
# max                  18.000000                       7782.000000
#
#        Structure.BelowGradeUnfinishedArea  Structure.FireplacesTotal  \
# count                        11674.000000               51216.000000
# mean                           649.350608                   0.941737
# std                            577.616585                   0.713055
# min                              0.000000                   0.000000
# 25%                            150.000000                   1.000000
# 50%                            565.500000                   1.000000
# 75%                           1000.000000                   1.000000
# max                           4896.000000                  21.000000
#
#        Structure.GarageSpaces  Structure.LivingArea  \
# count            88621.000000          99509.000000
# mean                 2.039585           1742.211448
# std                  8.542624           1144.743077
# min                  0.000000              0.000000
# 25%                  1.000000           1100.000000
# 50%                  2.000000           1550.000000
# 75%                  2.000000           2200.000000
# max                999.000000          51400.000000
#
#        Structure.Rooms.RoomsTotal  Structure.YearBuilt
# count               105061.000000        102256.000000
# mean                     7.174756          1969.155199
# std                      2.846424            53.661479
# min                      0.000000             0.000000
# 25%                      5.000000          1952.000000
# 50%                      7.000000          1973.000000
# 75%                      8.000000          1998.000000
# max                     99.000000          2024.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# The first step is to divide the data in Train and Validation

# %%
# divide train and validation data

from sklearn.model_selection import train_test_split

train, valid = train_test_split(df, test_size=0.2, random_state=42)

# %%
train['Structure.YearBuilt'] = train['Structure.YearBuilt'].astype('object')
train['Location.GIS.Latitude'] = train['Location.GIS.Latitude'].astype('object')
train['Location.GIS.Longitude'] = train['Location.GIS.Longitude'].astype('object')

valid['Structure.YearBuilt'] = valid['Structure.YearBuilt'].astype('object')
valid['Location.GIS.Latitude'] = valid['Location.GIS.Latitude'].astype('object')
valid['Location.GIS.Longitude'] = valid['Location.GIS.Longitude'].astype('object')

# %%
import pandas as pd
import numpy as np

def convert_to_missing(df):
    # Reemplazar todos los valores "missing" (NA, NaN, nan, None, '', 'none', 'na', etc.) con NaN
    missing_values = [None, 'NA', 'NaN', 'nan', '', 'none', 'na', 'Na', 'NULL']
    df = df.replace(missing_values, np.nan)
    return df

# Aplicar la función a los DataFrames de entrenamiento y validación
train = convert_to_missing(train)
valid = convert_to_missing(valid)

# Verificar que los valores faltantes hayan sido reemplazados
print(train.isna().sum())
print(valid.isna().sum())
# Out:
# Characteristics.LotFeatures               52372
# Characteristics.LotSizeSquareFeet         84588
# ImageData.c1c6.summary.bathroom           13386
# ImageData.c1c6.summary.exterior           15699
# ImageData.c1c6.summary.interior           11126
# ImageData.c1c6.summary.kitchen            12142
# ImageData.c1c6.summary.property            3485
# ImageData.features_reso.results            2139
# ImageData.q1q6.summary.bathroom           13415
# ImageData.q1q6.summary.exterior           19907
# ImageData.q1q6.summary.interior           11132
# ImageData.q1q6.summary.kitchen            12165
# ImageData.q1q6.summary.property            4498
# ImageData.room_type_reso.results            453
# ImageData.style.exterior.summary.label    19078
# ImageData.style.stories.summary.label     19231
# Listing.Dates.CloseDate                       0
# Listing.ListingId                             0
# Listing.Price.ClosePrice                      0
# Location.Address.CensusBlock               5525
# Location.Address.CensusTract               5525
# Location.Address.City                         0
# Location.Address.CountyOrParish             495
# Location.Address.PostalCode                   0
# Location.Address.PostalCodePlus4          83321
# Location.Address.StateOrProvince              0
# Location.Address.StreetDirectionPrefix    46975
# Location.Address.StreetDirectionSuffix    85429
# Location.Address.StreetName                   2
# Location.Address.StreetNumber                19
# Location.Address.StreetSuffix              1087
# Location.Address.UnitNumber               66274
# Location.Address.UnparsedAddress              0
# Location.Area.SubdivisionName             56740
# Location.GIS.Latitude                      5525
# Location.GIS.Longitude                     5525
# Location.School.HighSchoolDistrict         1764
# Property.PropertyType                         0
# Structure.Basement                         3690
# Structure.BathroomsFull                    5895
# Structure.BathroomsHalf                    5907
# Structure.BedroomsTotal                    1945
# Structure.BelowGradeFinishedArea          74587
# Structure.BelowGradeUnfinishedArea        76661
# Structure.Cooling                          4741
# Structure.FireplacesTotal                 45036
# Structure.GarageSpaces                    14994
# Structure.Heating                          1976
# Structure.LivingArea                       6333
# Structure.NewConstructionYN                 883
# Structure.ParkingFeatures                 75135
# Structure.Rooms.RoomsTotal                 1914
# Structure.YearBuilt                        4104
# Tax.Zoning                                79976
# UnitTypes.UnitTypeType                    81987
# dtype: int64
# Characteristics.LotFeatures               13045
# Characteristics.LotSizeSquareFeet         21159
# ImageData.c1c6.summary.bathroom            3307
# ImageData.c1c6.summary.exterior            3949
# ImageData.c1c6.summary.interior            2714
# ImageData.c1c6.summary.kitchen             2975
# ImageData.c1c6.summary.property             897
# ImageData.features_reso.results             518
# ImageData.q1q6.summary.bathroom            3314
# ImageData.q1q6.summary.exterior            4965
# ImageData.q1q6.summary.interior            2716
# ImageData.q1q6.summary.kitchen             2980
# ImageData.q1q6.summary.property            1141
# ImageData.room_type_reso.results            110
# ImageData.style.exterior.summary.label     4786
# ImageData.style.stories.summary.label      4855
# Listing.Dates.CloseDate                       0
# Listing.ListingId                             0
# Listing.Price.ClosePrice                      0
# Location.Address.CensusBlock               1472
# Location.Address.CensusTract               1472
# Location.Address.City                         0
# Location.Address.CountyOrParish             118
# Location.Address.PostalCode                   0
# Location.Address.PostalCodePlus4          20845
# Location.Address.StateOrProvince              0
# Location.Address.StreetDirectionPrefix    11768
# Location.Address.StreetDirectionSuffix    21367
# Location.Address.StreetName                   2
# Location.Address.StreetNumber                 6
# Location.Address.StreetSuffix               276
# Location.Address.UnitNumber               16624
# Location.Address.UnparsedAddress              0
# Location.Area.SubdivisionName             14156
# Location.GIS.Latitude                      1472
# Location.GIS.Longitude                     1472
# Location.School.HighSchoolDistrict          418
# Property.PropertyType                         0
# Structure.Basement                          919
# Structure.BathroomsFull                    1479
# Structure.BathroomsHalf                    1481
# Structure.BedroomsTotal                     468
# Structure.BelowGradeFinishedArea          18615
# Structure.BelowGradeUnfinishedArea        19102
# Structure.Cooling                          1209
# Structure.FireplacesTotal                 11185
# Structure.GarageSpaces                     3822
# Structure.Heating                           474
# Structure.LivingArea                       1595
# Structure.NewConstructionYN                 210
# Structure.ParkingFeatures                 18745
# Structure.Rooms.RoomsTotal                  462
# Structure.YearBuilt                        1077
# Tax.Zoning                                19963
# UnitTypes.UnitTypeType                    20474
# dtype: int64

# %%
# We create a table with the missing values and the percentage of missing values

missing_values = df.isnull().sum()
missing_values_percent = missing_values / len(df) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
#                                         Missing Values  Percentage
# Location.Address.StreetDirectionSuffix          106796   99.403371
# Characteristics.LotSizeSquareFeet               105747   98.426985
# Location.Address.PostalCodePlus4                104166   96.955425
# UnitTypes.UnitTypeType                          102461   95.368448
# Tax.Zoning                                       99939   93.021026
# Structure.BelowGradeUnfinishedArea               95763   89.134097
# Structure.ParkingFeatures                        93880   87.381442
# Structure.BelowGradeFinishedArea                 93202   86.750375
# Location.Address.UnitNumber                      82894   77.155915
# Location.Area.SubdivisionName                    70896   65.988440
# Characteristics.LotFeatures                      65417   60.888707
# Location.Address.StreetDirectionPrefix           58743   54.676694
# Structure.FireplacesTotal                        56221   52.329272
# ImageData.q1q6.summary.exterior                  24872   23.150311
# ImageData.style.stories.summary.label            24086   22.418720
# ImageData.style.exterior.summary.label           23864   22.212087
# ImageData.c1c6.summary.exterior                  19648   18.287927
# Structure.GarageSpaces                           18816   17.513520
# ImageData.q1q6.summary.bathroom                  16729   15.570986
# ImageData.c1c6.summary.bathroom                  16693   15.537478
# ImageData.q1q6.summary.kitchen                   15145   14.096633
# ImageData.c1c6.summary.kitchen                   15117   14.070572
# ImageData.q1q6.summary.interior                  13848   12.889414
# ImageData.c1c6.summary.interior                  13840   12.881968
# Structure.LivingArea                              7928    7.379208
# Structure.BathroomsHalf                           7388    6.876588
# Structure.BathroomsFull                           7374    6.863557
# Location.Address.CensusTract                      6997    6.512654
# Location.Address.CensusBlock                      6997    6.512654
# Location.GIS.Latitude                             6997    6.512654
# Location.GIS.Longitude                            6997    6.512654
# Structure.Cooling                                 5950    5.538129
# ImageData.q1q6.summary.property                   5639    5.248657
# Structure.YearBuilt                               5181    4.822361
# Structure.Basement                                4609    4.289956
# ImageData.c1c6.summary.property                   4382    4.078669
# ImageData.features_reso.results                   2657    2.473077
# Structure.Heating                                 2450    2.280406
# Structure.BedroomsTotal                           2413    2.245967
# Structure.Rooms.RoomsTotal                        2376    2.211529
# Location.School.HighSchoolDistrict                2182    2.030958
# Location.Address.StreetSuffix                     1363    1.268650
# Structure.NewConstructionYN                       1093    1.017340
# Location.Address.CountyOrParish                    613    0.570567
# ImageData.room_type_reso.results                   563    0.524028
# Location.Address.StreetNumber                       25    0.023269
# Location.Address.StreetName                          4    0.003723

# %%
# Mirar los valores unicos de street direction sufix
print(train['Location.Address.StreetDirectionSuffix'].unique())

# Mirar los valores unicos de street direction prefix
print(train['Location.Address.StreetDirectionPrefix'].unique())

# Unir las columnas anteriores en una que sea street direction
train['Location.Address.StreetDirection'] = train['Location.Address.StreetDirectionPrefix'].fillna('') + train['Location.Address.StreetDirectionSuffix'].fillna('')
valid['Location.Address.StreetDirection'] = valid['Location.Address.StreetDirectionPrefix'].fillna('') + valid['Location.Address.StreetDirectionSuffix'].fillna('')

# Eliminar las columnas que ya no necesitamos
train.drop(columns=['Location.Address.StreetDirectionPrefix', 'Location.Address.StreetDirectionSuffix'], inplace=True)
valid.drop(columns=['Location.Address.StreetDirectionPrefix', 'Location.Address.StreetDirectionSuffix'], inplace=True)

#Los NA en el formato correcto
train['Location.Address.StreetDirection'] = train['Location.Address.StreetDirection'].replace('', None)
valid['Location.Address.StreetDirection'] = valid['Location.Address.StreetDirection'].replace('', None)
# Out:
# [nan 'e' 'n' 'w' 's' 'se' 'sw' 'ne' 'nw']
# [nan 'e' 's' 'n' 'w' 'sw' 'ne' 'nw' 'se']

# %%
# Mirar los missing values de la nueva variable
print(train['Location.Address.StreetDirection'].isnull().sum())
print(valid['Location.Address.StreetDirection'].isnull().sum())

#calcular los porcentages de missings
print(train['Location.Address.StreetDirection'].isnull().sum()/len(train))
print(valid['Location.Address.StreetDirection'].isnull().sum()/len(valid))
# Out:
# 46632
# 11692
# 0.5425543054602148
# 0.5441176470588235

# %%
#Eliminem les columnes 
train.drop(columns=['Characteristics.LotSizeSquareFeet', 'Location.Address.PostalCodePlus4'], inplace=True)
valid.drop(columns=['Characteristics.LotSizeSquareFeet', 'Location.Address.PostalCodePlus4'], inplace=True)

# %%
# Eliminar las columnas que ya no necesitamos
train.drop(columns=['UnitTypes.UnitTypeType', 'Tax.Zoning'], inplace=True)
valid.drop(columns=['UnitTypes.UnitTypeType', 'Tax.Zoning'], inplace=True)

# Mirar los missing values de la nueva variable
missing_values = train.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
#                                         Missing Values  Percentage
# Structure.BelowGradeUnfinishedArea               76661   89.193592
# Structure.ParkingFeatures                        75135   87.418120
# Structure.BelowGradeFinishedArea                 74587   86.780533
# Location.Address.UnitNumber                      66274   77.108518
# Location.Area.SubdivisionName                    56740   66.015893
# Characteristics.LotFeatures                      52372   60.933810
# Location.Address.StreetDirection                 46632   54.255431
# Structure.FireplacesTotal                        45036   52.398515
# ImageData.q1q6.summary.exterior                  19907   23.161410
# ImageData.style.stories.summary.label            19231   22.374897
# ImageData.style.exterior.summary.label           19078   22.196884
# ImageData.c1c6.summary.exterior                  15699   18.265483
# Structure.GarageSpaces                           14994   17.445229
# ImageData.q1q6.summary.bathroom                  13415   15.608093
# ImageData.c1c6.summary.bathroom                  13386   15.574352
# ImageData.q1q6.summary.kitchen                   12165   14.153742
# ImageData.c1c6.summary.kitchen                   12142   14.126982
# ImageData.q1q6.summary.interior                  11132   12.951867
# ImageData.c1c6.summary.interior                  11126   12.944886
# Structure.LivingArea                              6333    7.368323
# Structure.BathroomsHalf                           5907    6.872680
# Structure.BathroomsFull                           5895    6.858719
# Location.Address.CensusBlock                      5525    6.428231
# Location.GIS.Longitude                            5525    6.428231
# Location.Address.CensusTract                      5525    6.428231
# Location.GIS.Latitude                             5525    6.428231
# Structure.Cooling                                 4741    5.516062
# ImageData.q1q6.summary.property                   4498    5.233336
# Structure.YearBuilt                               4104    4.774925
# Structure.Basement                                3690    4.293244
# ImageData.c1c6.summary.property                   3485    4.054730
# ImageData.features_reso.results                   2139    2.488685
# Structure.Heating                                 1976    2.299038
# Structure.BedroomsTotal                           1945    2.262970
# Structure.Rooms.RoomsTotal                        1914    2.226902
# Location.School.HighSchoolDistrict                1764    2.052380
# Location.Address.StreetSuffix                     1087    1.264703
# Structure.NewConstructionYN                        883    1.027353
# Location.Address.CountyOrParish                    495    0.575923
# ImageData.room_type_reso.results                   453    0.527057
# Location.Address.StreetNumber                       19    0.022106
# Location.Address.StreetName                          2    0.002327

# %%
#Structure.ParkingFeatures si tiene resultado 1 si no 0
train['Structure.ParkingFeatures'] = train['Structure.ParkingFeatures'].notnull().astype(int)
valid['Structure.ParkingFeatures'] = valid['Structure.ParkingFeatures'].notnull().astype(int)

# Mirar los missing values de la nueva variable
missing_values = train.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
#                                         Missing Values  Percentage
# Structure.BelowGradeUnfinishedArea               76661   89.193592
# Structure.BelowGradeFinishedArea                 74587   86.780533
# Location.Address.UnitNumber                      66274   77.108518
# Location.Area.SubdivisionName                    56740   66.015893
# Characteristics.LotFeatures                      52372   60.933810
# Location.Address.StreetDirection                 46632   54.255431
# Structure.FireplacesTotal                        45036   52.398515
# ImageData.q1q6.summary.exterior                  19907   23.161410
# ImageData.style.stories.summary.label            19231   22.374897
# ImageData.style.exterior.summary.label           19078   22.196884
# ImageData.c1c6.summary.exterior                  15699   18.265483
# Structure.GarageSpaces                           14994   17.445229
# ImageData.q1q6.summary.bathroom                  13415   15.608093
# ImageData.c1c6.summary.bathroom                  13386   15.574352
# ImageData.q1q6.summary.kitchen                   12165   14.153742
# ImageData.c1c6.summary.kitchen                   12142   14.126982
# ImageData.q1q6.summary.interior                  11132   12.951867
# ImageData.c1c6.summary.interior                  11126   12.944886
# Structure.LivingArea                              6333    7.368323
# Structure.BathroomsHalf                           5907    6.872680
# Structure.BathroomsFull                           5895    6.858719
# Location.GIS.Latitude                             5525    6.428231
# Location.GIS.Longitude                            5525    6.428231
# Location.Address.CensusBlock                      5525    6.428231
# Location.Address.CensusTract                      5525    6.428231
# Structure.Cooling                                 4741    5.516062
# ImageData.q1q6.summary.property                   4498    5.233336
# Structure.YearBuilt                               4104    4.774925
# Structure.Basement                                3690    4.293244
# ImageData.c1c6.summary.property                   3485    4.054730
# ImageData.features_reso.results                   2139    2.488685
# Structure.Heating                                 1976    2.299038
# Structure.BedroomsTotal                           1945    2.262970
# Structure.Rooms.RoomsTotal                        1914    2.226902
# Location.School.HighSchoolDistrict                1764    2.052380
# Location.Address.StreetSuffix                     1087    1.264703
# Structure.NewConstructionYN                        883    1.027353
# Location.Address.CountyOrParish                    495    0.575923
# ImageData.room_type_reso.results                   453    0.527057
# Location.Address.StreetNumber                       19    0.022106
# Location.Address.StreetName                          2    0.002327

# %%
# Unknown a Location.Area.SubdivisionName   
train['Location.Area.SubdivisionName'] = train['Location.Area.SubdivisionName'].replace('', None)
valid['Location.Area.SubdivisionName'] = valid['Location.Area.SubdivisionName'].replace('', None)

# Mirar los missing values de la nueva variable
missing_values = train.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
#                                         Missing Values  Percentage
# Structure.BelowGradeUnfinishedArea               76661   89.193592
# Structure.BelowGradeFinishedArea                 74587   86.780533
# Location.Address.UnitNumber                      66274   77.108518
# Location.Area.SubdivisionName                    56740   66.015893
# Characteristics.LotFeatures                      52372   60.933810
# Location.Address.StreetDirection                 46632   54.255431
# Structure.FireplacesTotal                        45036   52.398515
# ImageData.q1q6.summary.exterior                  19907   23.161410
# ImageData.style.stories.summary.label            19231   22.374897
# ImageData.style.exterior.summary.label           19078   22.196884
# ImageData.c1c6.summary.exterior                  15699   18.265483
# Structure.GarageSpaces                           14994   17.445229
# ImageData.q1q6.summary.bathroom                  13415   15.608093
# ImageData.c1c6.summary.bathroom                  13386   15.574352
# ImageData.q1q6.summary.kitchen                   12165   14.153742
# ImageData.c1c6.summary.kitchen                   12142   14.126982
# ImageData.q1q6.summary.interior                  11132   12.951867
# ImageData.c1c6.summary.interior                  11126   12.944886
# Structure.LivingArea                              6333    7.368323
# Structure.BathroomsHalf                           5907    6.872680
# Structure.BathroomsFull                           5895    6.858719
# Location.GIS.Latitude                             5525    6.428231
# Location.GIS.Longitude                            5525    6.428231
# Location.Address.CensusBlock                      5525    6.428231
# Location.Address.CensusTract                      5525    6.428231
# Structure.Cooling                                 4741    5.516062
# ImageData.q1q6.summary.property                   4498    5.233336
# Structure.YearBuilt                               4104    4.774925
# Structure.Basement                                3690    4.293244
# ImageData.c1c6.summary.property                   3485    4.054730
# ImageData.features_reso.results                   2139    2.488685
# Structure.Heating                                 1976    2.299038
# Structure.BedroomsTotal                           1945    2.262970
# Structure.Rooms.RoomsTotal                        1914    2.226902
# Location.School.HighSchoolDistrict                1764    2.052380
# Location.Address.StreetSuffix                     1087    1.264703
# Structure.NewConstructionYN                        883    1.027353
# Location.Address.CountyOrParish                    495    0.575923
# ImageData.room_type_reso.results                   453    0.527057
# Location.Address.StreetNumber                       19    0.022106
# Location.Address.StreetName                          2    0.002327

# %%
#Eliminar la Location.Address.UnitNumber
train.drop(columns=['Location.Address.UnitNumber'], inplace=True)
valid.drop(columns=['Location.Address.UnitNumber'], inplace=True)

# %%
#Mirar los valores unicos de la variable Location.Address.StateOrProvince
print(train['Location.Address.StateOrProvince'].unique())
train.drop(columns=['Location.Address.StateOrProvince'], inplace=True)
valid.drop(columns=['Location.Address.StateOrProvince'], inplace=True)
# Out:
# ['il']

# %%
missing_values = train.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
#                                         Missing Values  Percentage
# Structure.BelowGradeUnfinishedArea               76661   89.193592
# Structure.BelowGradeFinishedArea                 74587   86.780533
# Location.Area.SubdivisionName                    56740   66.015893
# Characteristics.LotFeatures                      52372   60.933810
# Location.Address.StreetDirection                 46632   54.255431
# Structure.FireplacesTotal                        45036   52.398515
# ImageData.q1q6.summary.exterior                  19907   23.161410
# ImageData.style.stories.summary.label            19231   22.374897
# ImageData.style.exterior.summary.label           19078   22.196884
# ImageData.c1c6.summary.exterior                  15699   18.265483
# Structure.GarageSpaces                           14994   17.445229
# ImageData.q1q6.summary.bathroom                  13415   15.608093
# ImageData.c1c6.summary.bathroom                  13386   15.574352
# ImageData.q1q6.summary.kitchen                   12165   14.153742
# ImageData.c1c6.summary.kitchen                   12142   14.126982
# ImageData.q1q6.summary.interior                  11132   12.951867
# ImageData.c1c6.summary.interior                  11126   12.944886
# Structure.LivingArea                              6333    7.368323
# Structure.BathroomsHalf                           5907    6.872680
# Structure.BathroomsFull                           5895    6.858719
# Location.GIS.Longitude                            5525    6.428231
# Location.GIS.Latitude                             5525    6.428231
# Location.Address.CensusTract                      5525    6.428231
# Location.Address.CensusBlock                      5525    6.428231
# Structure.Cooling                                 4741    5.516062
# ImageData.q1q6.summary.property                   4498    5.233336
# Structure.YearBuilt                               4104    4.774925
# Structure.Basement                                3690    4.293244
# ImageData.c1c6.summary.property                   3485    4.054730
# ImageData.features_reso.results                   2139    2.488685
# Structure.Heating                                 1976    2.299038
# Structure.BedroomsTotal                           1945    2.262970
# Structure.Rooms.RoomsTotal                        1914    2.226902
# Location.School.HighSchoolDistrict                1764    2.052380
# Location.Address.StreetSuffix                     1087    1.264703
# Structure.NewConstructionYN                        883    1.027353
# Location.Address.CountyOrParish                    495    0.575923
# ImageData.room_type_reso.results                   453    0.527057
# Location.Address.StreetNumber                       19    0.022106
# Location.Address.StreetName                          2    0.002327

# %%
#Structure.Basement si es missing o ['none'] es 0 si no 1
train['Structure.Basement'] = train['Structure.Basement'].replace(['none'], None)
valid['Structure.Basement'] = valid['Structure.Basement'].replace(['none'], None)   
train['Structure.Basement'] = train['Structure.Basement'].notnull().astype(int)
valid['Structure.Basement'] = valid['Structure.Basement'].notnull().astype(int)

# %%
# Los valores faltantes de Structure.GarageSpaces se ponen a 0
train['Structure.GarageSpaces'] = train['Structure.GarageSpaces'].fillna(0)
valid['Structure.GarageSpaces'] = valid['Structure.GarageSpaces'].fillna(0)

# %%
# cogemos de esta variable ImageData.style.stories.summary.label el digito del valor de la variable (siempre es el primero) y los nulos a 1
# lo hacemos con re.sub
import re

# Función para extraer los primeros dígitos y hacer las modificaciones necesarias
def extract_and_adjust(value):
    # Extraemos los dígitos del valor (tanto enteros como decimales)
    number_str = re.sub(r'\D', '', str(value))
    if number_str:
        number = float(number_str)
        # Si el número es mayor a 10, lo dividimos por 10
        if number > 10:
            return number / 10
        else:
            return float(number)
    return 1  # Valor por defecto si no se encuentra ningún número

# Aplicamos la función a las columnas correspondientes
train['ImageData.style.stories.summary.label'] = train['ImageData.style.stories.summary.label'].apply(extract_and_adjust)
valid['ImageData.style.stories.summary.label'] = valid['ImageData.style.stories.summary.label'].apply(extract_and_adjust)

# print the unique values of the variable
print(train['ImageData.style.stories.summary.label'].unique())
# Out:
# [2.5 1.  2.  1.5 3. ]

# %%
from fancyimpute import IterativeImputer

# Lista de columnas que queremos imputar
columns_to_impute = [
    "ImageData.q1q6.summary.bathroom",
    "ImageData.c1c6.summary.bathroom",
    "ImageData.q1q6.summary.kitchen",
    "ImageData.c1c6.summary.kitchen",
    "ImageData.q1q6.summary.interior",
    "ImageData.c1c6.summary.interior",
    "ImageData.q1q6.summary.exterior",
    "ImageData.c1c6.summary.exterior",
    "ImageData.q1q6.summary.property",
    "ImageData.c1c6.summary.property",
    "Structure.LivingArea"
]

# Verifica si las columnas están en el DataFrame
columns_in_train = [col for col in columns_to_impute if col in train.columns]
missing_columns = [col for col in columns_to_impute if col not in train.columns]

# Imprime las columnas faltantes, si hay alguna
if missing_columns:
    print(f"Estas columnas no están en el DataFrame: {missing_columns}")

# Imputar los datos solo para las columnas presentes
imputer = IterativeImputer()
imputed_data = imputer.fit_transform(train[columns_in_train])
data_val = imputer.transform(valid[columns_in_train])

# Reemplazar las columnas originales con los valores imputados
train[columns_in_train] = imputed_data
valid[columns_in_train] = data_val

# %%
import numpy as np

# Crear la columna combinada (media de las dos columnas después de imputar)
train['ImageData.summary.exterior'] = (train['ImageData.c1c6.summary.property'] + train['ImageData.q1q6.summary.property']) / 2
valid['ImageData.summary.exterior'] = (valid['ImageData.c1c6.summary.property'] + valid['ImageData.q1q6.summary.property']) / 2

# Eliminar las columnas originales (opcional)
train.drop(columns=['ImageData.c1c6.summary.property', 'ImageData.q1q6.summary.property'], inplace=True)
valid.drop(columns=['ImageData.c1c6.summary.property', 'ImageData.q1q6.summary.property'], inplace=True)

# %%
# juntamos ImageData.c1c6.summary.exterior, ImageData.q1q6.summary.exterior con la media de los valores no nulos
train['ImageData.q1q6.summary.interior'] = train['ImageData.q1q6.summary.interior'].astype(float)
train['ImageData.c1c6.summary.interior'] = train['ImageData.c1c6.summary.interior'].astype(float)
train['ImageData.summary.interior'] = (train['ImageData.c1c6.summary.interior'] + train['ImageData.q1q6.summary.interior']) / 2

valid['ImageData.q1q6.summary.interior'] = valid['ImageData.q1q6.summary.interior'].astype(float)
valid['ImageData.c1c6.summary.interior'] = valid['ImageData.c1c6.summary.interior'].astype(float)
valid['ImageData.summary.interior'] = (valid['ImageData.c1c6.summary.interior'] + valid['ImageData.q1q6.summary.interior']) / 2

# Eliminar las columnas que ya no necesitamos
train.drop(columns=['ImageData.c1c6.summary.interior', 'ImageData.q1q6.summary.interior'], inplace=True)
valid.drop(columns=['ImageData.c1c6.summary.interior', 'ImageData.q1q6.summary.interior'], inplace=True)

# %%
train['ImageData.q1q6.summary.bathroom'] = train['ImageData.q1q6.summary.bathroom'].astype(float)
train['ImageData.c1c6.summary.bathroom'] = train['ImageData.c1c6.summary.bathroom'].astype(float)
train['ImageData.summary.bathroom'] = (train['ImageData.q1q6.summary.bathroom'] + train['ImageData.c1c6.summary.bathroom']) / 2

valid['ImageData.q1q6.summary.bathroom'] = valid['ImageData.q1q6.summary.bathroom'].astype(float)
valid['ImageData.c1c6.summary.bathroom'] = valid['ImageData.c1c6.summary.bathroom'].astype(float)
valid['ImageData.summary.bathroom'] = (valid['ImageData.c1c6.summary.bathroom'] + valid['ImageData.q1q6.summary.bathroom']) / 2


# Eliminar las columnas que ya no necesitamos
train.drop(columns=['ImageData.q1q6.summary.bathroom', 'ImageData.c1c6.summary.bathroom'], inplace=True)
valid.drop(columns=['ImageData.q1q6.summary.bathroom', 'ImageData.c1c6.summary.bathroom'], inplace=True)

# %%
train['ImageData.q1q6.summary.kitchen'] = train['ImageData.q1q6.summary.kitchen'].astype(float)
train['ImageData.c1c6.summary.kitchen'] = train['ImageData.c1c6.summary.kitchen'].astype(float)
train['ImageData.summary.kitchen'] = (train['ImageData.q1q6.summary.kitchen'] + train['ImageData.c1c6.summary.kitchen']) / 2

valid['ImageData.q1q6.summary.kitchen'] = valid['ImageData.q1q6.summary.kitchen'].astype(float)
valid['ImageData.c1c6.summary.kitchen'] = valid['ImageData.c1c6.summary.kitchen'].astype(float)
valid['ImageData.summary.kitchen'] = (valid['ImageData.c1c6.summary.kitchen'] + valid['ImageData.q1q6.summary.kitchen']) / 2

# Eliminar las columnas que ya no necesitamos
train.drop(columns=['ImageData.q1q6.summary.kitchen', 'ImageData.c1c6.summary.kitchen'], inplace=True)
valid.drop(columns=['ImageData.q1q6.summary.kitchen', 'ImageData.c1c6.summary.kitchen'], inplace=True)

# %%
# Reemplazamos Location.Address.CountyOrParish y Location.Address.StreetName de missing a categoria Unknown
train['Location.Address.CountyOrParish'] = train['Location.Address.CountyOrParish'].replace(np.nan, 'Unknown')
train['Location.Address.StreetName'] = train['Location.Address.StreetName'].replace(np.nan, 'Unknown')

valid['Location.Address.CountyOrParish'] = valid['Location.Address.CountyOrParish'].replace(np.nan, 'Unknown')
valid['Location.Address.StreetName'] = valid['Location.Address.StreetName'].replace(np.nan, 'Unknown')

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\nuria\.conda\envs\aprns\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\nuria\.conda\envs\aprns\lib\site-packages (from geopy) (2.0)

# %%
# ImageData.style.exterior.summary.label missings a unknown
train['ImageData.style.exterior.summary.label'] = train['ImageData.style.exterior.summary.label'].replace(np.nan, 'Unknown')
valid['ImageData.style.exterior.summary.label'] = valid['ImageData.style.exterior.summary.label'].replace(np.nan, 'Unknown')

# %%
#girem les columnes de latitude i longitude
# Intercambiar las columnas de latitud y longitud
train['Location.GIS.Latitude'], train['Location.GIS.Longitude'] = train['Location.GIS.Longitude'], train['Location.GIS.Latitude']
valid['Location.GIS.Latitude'], valid['Location.GIS.Longitude'] = valid['Location.GIS.Longitude'], valid['Location.GIS.Latitude']

# %%
# Location.Address.StreetSuffix los missings por Unknown
train['Location.Address.StreetSuffix'] = train['Location.Address.StreetSuffix'].replace(np.nan, 'Unknown')
valid['Location.Address.StreetSuffix'] = valid['Location.Address.StreetSuffix'].replace(np.nan, 'Unknown')

# %%
#Structure.NewConstructionYN miramos la edad de la casa y si es nueva o no
train['Structure.NewConstructionYN'] = (train['Structure.YearBuilt'] <= 1).astype(int)
valid['Structure.NewConstructionYN'] = (valid['Structure.YearBuilt'] <= 1).astype(int)

# %%
# Borrar street number
train.drop(columns=['Location.Address.StreetNumber'], inplace=True)
valid.drop(columns=['Location.Address.StreetNumber'], inplace=True)

#Street Name missings a Unknown
train['Location.Address.StreetName'] = train['Location.Address.StreetName'].replace('', 'Unknown')
valid['Location.Address.StreetName'] = valid['Location.Address.StreetName'].replace('', 'Unknown')

# %%
import ast

# Función para convertir cadenas que parecen listas en listas reales y tomar el primer valor si es una lista
def convert_to_first_value(x):
    if isinstance(x, str):
        try:
            # Intentar convertir la cadena a una lista real
            x = ast.literal_eval(x)
        except (ValueError, SyntaxError):
            pass  # Si no se puede convertir, dejamos el valor tal cual
    if isinstance(x, list) and len(x) > 0:
        return x[0]  # Si es una lista, devolver el primer valor
    return x  # Si no es una lista, devolver el valor tal cual

# Aplicar la función a la columna 'Location.School.HighSchoolDistrict'
train['Location.School.HighSchoolDistrict'] = train['Location.School.HighSchoolDistrict'].apply(convert_to_first_value)
valid['Location.School.HighSchoolDistrict'] = valid['Location.School.HighSchoolDistrict'].apply(convert_to_first_value)

# Verificar los valores únicos después de la modificación
print(train['Location.School.HighSchoolDistrict'].unique())
# Out:
# [200 '158' 308 '154' 155 4 299 227 219 205 60 nan 125 202 203 '299' '60'
#  '207' 99 101 12 '202' 225 120 '87' 307 '140' 68 204 207 430 '5' 100 233
#  118 '208' '46' 211 '424' 303 302 217 229 215 25 201 '210' 129 '215' 220
#  '214' 158 '155' '120' 212 '116' 5 '61' '129' 1 '127' 46 170 90 122 427
#  '101' 117 137 209 111 '99' 228 131 214 '225' 156 230 '200' 127 88 '401'
#  126 432 '205' '125' '212' 300 '201' 208 '204' 87 16 502 61 '201u' '4' '1'
#  '126' 121 210 124 '218' '86' 94 130 218 'chris' 40 '8' 206 223 301 73 116
#  '115' '3' 86 95 128 '200u' 113 500 143.5 '111' 145 424 11 '170' '255u'
#  '128' '88' 10 '117' '228' 2 'other' '100' '209' 187 '230' '303' 426 '701'
#  '301' 231 108 '229' '233' '211' '219' '427' 193 18 154 '203' '95' '275'
#  '307' '193' 140 '207u' '308' '15' '220' 305 428 304 323 157 '365u' '227'
#  15 '300' '122' 21 '108' 3 '304' 7 '96' '217' '6' 221 54 160 '6-j' '302'
#  '305' '131' '2' 401 '113' '18' '118' 115 74 6 314 '137' '21' '121' '156'
#  165 425 8 '206' 9 '124' 50 152 429 '161' '535' 234 '80' 'richl' '93' 150
#  222 '234' 149 '94' 'arthu' '231' 151 226 76 '40' 701 275 19 103 '222'
#  '280' '25' '16' '340' 31 '428' '320' '500' '10' '209u' '512' '145' '7'
#  '152' 322 162 404 92 123 'selma' '11' '12' '502' '19' '109' '77' 399 256
#  '194' 186 97 '2c' 112 535 163 272 '74' '438' 65 148 '426' 53 '430' 30
#  '226' '97' '90' '429' 152.5 '4c' '50' '113a' 340 320 '223' 'osweg' '76'
#  153 '151' '187' 180 '130' 20 6j '53' '160' 512 13 89 '92.5' 144 64 41 77
#  91 709 '432' 168 280 'cowde' 143 169 '9' 23 39 '157' '63' 58 34 47 '271'
#  '399' '73' '703' 'pleas' 259 249 109 'sprin' 'triva' '123' 213 '425'
#  '314' '112' '54' '104' 110 '135' '26' 127.5 '27' 73.5 62 135 '148' 703
#  '23' '89' '44' 79 '272' '30' 321 438 104 132 '171' '5a' '146' '4151' 2918
#  '103' 505 114 22 35 167 '150' '68' '163' '154.5' 26 276 702 '22' 141
#  '169' '92' 142 93 '144' '70' '57' 232 'ballc' '127.5' '85.5' 181 '152.5'
#  '102' 146 '3c' '47' '323' '17' 96 '168' 271 224 '56' 188 '142' '147'
#  '322' 309 '39' 154.5 '289' 33 98 'roche' '221' 84 '66' '132' 66 147 '149'
#  '65' 306 '75' 27 '157c' 44 '91' 57 '37' 'colli' 194 '73.5' 'litch' '33c'
#  63 17 70 161 37 102 '316' '256' 75 '20' '6j' '321' 56 '64' '143.5' 0 '58'
#  '404' '505' '84' '114' 133 'lawre' '30c' 80 159 '34' 134 '29' '62' '41'
#  '33' 83 '159' '162' 81 '153' 92.5 '249' 191 67 '181' 'murph' '67' '141'
#  '72c' 326 '189']

# %%
# Quitamos los warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from geopy.distance import geodesic
from collections import defaultdict
import numpy as np

# Función para calcular la distancia entre dos coordenadas (latitud, longitud)
def calculate_distance(lat1, lon1, lat2, lon2):
    return geodesic((lat1, lon1), (lat2, lon2)).km

# Precalcular las distancias entre las casas dentro de cada código postal y almacenar los nombres de las escuelas
def precalculate_distances(train_df):
    print('precalculate_distances')
    distances = defaultdict(list)
    
    # Iteramos sobre las casas para organizar por código postal
    for idx, house in train_df.iterrows():
        house_lat = house['Location.GIS.Latitude']
        house_lon = house['Location.GIS.Longitude']
        postal_code = house['Location.Address.CensusBlock']
        school_name = house['Location.School.HighSchoolDistrict']
        
        # Validar que los valores necesarios existan
        if not pd.isna(house_lat) and not pd.isna(house_lon) and not pd.isna(postal_code):
            distances[postal_code].append((house_lat, house_lon, school_name))  # Guardamos la escuela
    
    return distances

# Función para obtener la escuela más cercana
def get_nearest_school(lat, lon, postal_code, distances):
    # Buscar la escuela más cercana dentro del mismo código postal
    if postal_code not in distances:
        return 'unknown'  # Si no hay casas en el código postal, devolvemos 'unknown'
    
    # Ordenar las casas dentro del mismo código postal por distancia
    distances_sorted = sorted(distances[postal_code], key=lambda x: calculate_distance(lat, lon, x[0], x[1]))
    
    # Buscar el primer nombre de escuela no nulo
    for _, _, school_name in distances_sorted:
        if school_name:  # Si encontramos una escuela válida
            return school_name
    
    return 'unknown'  # Si no se encontró ninguna escuela válida

# Función para llenar los valores faltantes de 'Location.School.HighSchoolDistrict'
def fill_missing_districts(df, distances):
    print('fill_missing_districts')

    # Aplicar la función para buscar escuelas cercanas solo en filas donde falte el distrito escolar
    missing_idx = df['Location.School.HighSchoolDistrict'].isna()
    df.loc[missing_idx, 'Location.School.HighSchoolDistrict'] = df[missing_idx].apply(
        lambda row: get_nearest_school(row['Location.GIS.Latitude'], 
                                       row['Location.GIS.Longitude'], 
                                       row['Location.Address.CensusBlock'], 
                                       distances),
        axis=1
    )

    # Reemplazar cualquier valor faltante restante con "unknown"
    df['Location.School.HighSchoolDistrict'] = df['Location.School.HighSchoolDistrict'].fillna('unknown')
    return df

# Precalcular las distancias para el DataFrame de entrenamiento
distances = precalculate_distances(train)

# Llenar valores faltantes en 'train' y 'valid'
train = fill_missing_districts(train, distances)
valid = fill_missing_districts(valid, distances)

# Verificar que no haya valores faltantes
assert train['Location.School.HighSchoolDistrict'].isna().sum() == 0, "Quedan valores faltantes en train"
assert valid['Location.School.HighSchoolDistrict'].isna().sum() == 0, "Quedan valores faltantes en valid"

print("Todos los valores faltantes han sido rellenados.")
# Out:
# precalculate_distances
# fill_missing_districts
# fill_missing_districts
# Todos los valores faltantes han sido rellenados.

# %%
# Structure.BathroomsHalf, Structure.BathroomsFull los NA los ponemos a 0
train['Structure.BathroomsHalf'] = train['Structure.BathroomsHalf'].fillna(0)
valid['Structure.BathroomsHalf'] = valid['Structure.BathroomsHalf'].fillna(0)

train['Structure.BathroomsFull'] = train['Structure.BathroomsFull'].fillna(0)
valid['Structure.BathroomsFull'] = valid['Structure.BathroomsFull'].fillna(0)

# %%
#Structure.Rooms.RoomsTotal los NA los ponemos a 0
train['Structure.Rooms.RoomsTotal'] = train['Structure.Rooms.RoomsTotal'].fillna(0)
valid['Structure.Rooms.RoomsTotal'] = valid['Structure.Rooms.RoomsTotal'].fillna(0)

# %%
# Structure.BedroomsTotal  los NA los ponemos a 0
train['Structure.BedroomsTotal'] = train['Structure.BedroomsTotal'].fillna(0)
valid['Structure.BedroomsTotal'] = valid['Structure.BedroomsTotal'].fillna(0)

# %%
# Structure.FireplacesTotal los NA a 0
train['Structure.FireplacesTotal'] = train['Structure.FireplacesTotal'].fillna(0)
valid['Structure.FireplacesTotal'] = valid['Structure.FireplacesTotal'].fillna(0)

# %%
# Pels missing Location.GIS.Longitude,Location.GIS.Latitude calculem el valor mitja segons Location.Address.PostalCode
train['Location.GIS.Longitude'] = train['Location.GIS.Longitude'].fillna(train.groupby('Location.Address.PostalCode')['Location.GIS.Longitude'].transform('mean'))
train['Location.GIS.Latitude'] = train['Location.GIS.Latitude'].fillna(train.groupby('Location.Address.PostalCode')['Location.GIS.Latitude'].transform('mean'))

valid['Location.GIS.Longitude'] = valid['Location.GIS.Longitude'].fillna(valid.groupby('Location.Address.PostalCode')['Location.GIS.Longitude'].transform('mean'))
valid['Location.GIS.Latitude'] = valid['Location.GIS.Latitude'].fillna(valid.groupby('Location.Address.PostalCode')['Location.GIS.Latitude'].transform('mean'))

# %%
def fill_mode(group):
    mode_value = group.mode()
    if not mode_value.empty:
        return mode_value.iloc[0]
    return group.iloc[0]  

train['Location.Address.CensusBlock'] = train.groupby('Location.Address.PostalCode')['Location.Address.CensusBlock'].transform(fill_mode)
train['Location.Address.CensusTract'] = train.groupby('Location.Address.PostalCode')['Location.Address.CensusTract'].transform(fill_mode)

valid['Location.Address.CensusBlock'] = valid.groupby('Location.Address.PostalCode')['Location.Address.CensusBlock'].transform(fill_mode)
valid['Location.Address.CensusTract'] = valid.groupby('Location.Address.PostalCode')['Location.Address.CensusTract'].transform(fill_mode)

# %%
#borrar las rows de Location.Address.CensusBlock, Location.Address.CensusTract que tienen missing

train = train.dropna(subset=['Location.Address.CensusBlock', 'Location.Address.CensusTract'])
valid = valid.dropna(subset=['Location.Address.CensusBlock', 'Location.Address.CensusTract'])

# %%
# Structure.BelowGradeUnfinishedArea, Structure.BelowGradeFinishedArea los NA a 0
train['Structure.BelowGradeUnfinishedArea'] = train['Structure.BelowGradeUnfinishedArea'].fillna(0)
train['Structure.BelowGradeFinishedArea'] = train['Structure.BelowGradeFinishedArea'].fillna(0)
valid['Structure.BelowGradeUnfinishedArea'] = valid['Structure.BelowGradeUnfinishedArea'].fillna(0)
valid['Structure.BelowGradeFinishedArea'] = valid['Structure.BelowGradeFinishedArea'].fillna(0)

# %%
# Location.Area.SubdivisionName los NA a Unknown (substituir en un futur) 
train['Location.Area.SubdivisionName'] = train['Location.Area.SubdivisionName'].fillna('Unknown')
valid['Location.Area.SubdivisionName'] = valid['Location.Area.SubdivisionName'].fillna('Unknown')

# %%
train['Location.Address.StreetDirection'] = train['Location.Address.StreetDirection'].fillna('Unknown')
valid['Location.Address.StreetDirection'] = valid['Location.Address.StreetDirection'].fillna('Unknown')

# %%
#Structure.FireplacesTotal   los NA a 0
train['Structure.FireplacesTotal'] = train['Structure.FireplacesTotal'].fillna(0)
valid['Structure.FireplacesTotal'] = valid['Structure.FireplacesTotal'].fillna(0)

# %%
#En el year built calcular la edad de la casa (2024 - year built)
train['Structure.YearBuilt'] = 2024 - train['Structure.YearBuilt']
valid['Structure.YearBuilt'] = 2024 - valid['Structure.YearBuilt']

#Structure.YearBuilt los NA a la mediana
train['Structure.YearBuilt'] = train['Structure.YearBuilt'].fillna(train['Structure.YearBuilt'].median())
valid['Structure.YearBuilt'] = valid['Structure.YearBuilt'].fillna(valid['Structure.YearBuilt'].median())

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import spearmanr
from scipy.stats import f_oneway

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales
# Si hay valores NaN, los reemplazamos con ['Unknown']
train['ImageData.features_reso.results'] = train['ImageData.features_reso.results'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer para transformar las listas en variables binarias
mlb = MultiLabelBinarizer()
binary_features = mlb.fit_transform(train['ImageData.features_reso.results'])
binary_df = pd.DataFrame(binary_features, columns=mlb.classes_, index=train.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame original
binary_df.columns = [col + '_features' for col in binary_df.columns]
df = pd.concat([train, binary_df], axis=1)

# Paso 4: Realizar ANOVA para cada variable binarizada
anova_results = {}
for column in binary_df.columns:
    # Dividir la variable continua en grupos según la variable binaria
    group_0 = df[df[column] == 0]['Listing.Price.ClosePrice']
    group_1 = df[df[column] == 1]['Listing.Price.ClosePrice']
    
    # Calcular ANOVA
    if len(group_0) > 1 and len(group_1) > 1:  # Asegurarse de que hay suficientes datos en ambos grupos
        f_stat, p_value = f_oneway(group_0, group_1)
        anova_results[column] = (f_stat, p_value)
    else:
        anova_results[column] = (None, None)  # Insuficientes datos para el ANOVA

# Paso 5: Ordenar los resultados por el estadístico F
sorted_anova = sorted(anova_results.items(), key=lambda x: x[1][0] if x[1][0] is not None else 0, reverse=True)

# Paso 6: Filtrar características importantes según p-valor
threshold_p_value = 0.05
important_features = [feature for feature, (f_stat, p_value) in anova_results.items() if p_value is not None and p_value < threshold_p_value]

# Mostrar resultados
print("Resultados de ANOVA ordenados (por estadístico F):")
for feature, (f_stat, p_value) in sorted_anova:
    if f_stat is not None:
        print(f"{feature}: Estadístico F={f_stat:.3f}, p-valor={p_value:.3f}")

print("\nCaracterísticas importantes (p-valor < 0.05):", important_features)

significant_binary_df = binary_df[important_features]
train = pd.concat([train, significant_binary_df], axis=1)
# Out:
# Resultados de ANOVA ordenados (por estadístico F):
# Appliances.BuiltInRefrigerator_features: Estadístico F=7089.580, p-valor=0.000
# InteriorOrRoomFeatures.KitchenIsland_features: Estadístico F=6485.576, p-valor=0.000
# Appliances.Oven_features: Estadístico F=6245.462, p-valor=0.000
# InteriorOrRoomFeatures.DoubleVanity_features: Estadístico F=5151.486, p-valor=0.000
# Appliances.WineCooler_features: Estadístico F=4857.708, p-valor=0.000
# Appliances.Cooktop_features: Estadístico F=4840.727, p-valor=0.000
# InteriorOrRoomFeatures.BreakfastBar_features: Estadístico F=4724.784, p-valor=0.000
# Appliances.GasCooktop_features: Estadístico F=4717.824, p-valor=0.000
# Appliances.DoubleOven_features: Estadístico F=3781.025, p-valor=0.000
# Heating.Fireplaces_features: Estadístico F=3627.259, p-valor=0.000
# InteriorOrRoomFeatures.BuiltInFeatures_features: Estadístico F=3494.007, p-valor=0.000
# InteriorOrRoomFeatures.TrayCeilings_features: Estadístico F=3380.117, p-valor=0.000
# DoorFeatures.FrenchDoors_features: Estadístico F=3305.581, p-valor=0.000
# InteriorOrRoomFeatures.CofferedCeilings_features: Estadístico F=2949.880, p-valor=0.000
# InteriorOrRoomFeatures.StoneCounters_features: Estadístico F=2396.558, p-valor=0.000
# InteriorOrRoomFeatures.Bar_features: Estadístico F=2300.498, p-valor=0.000
# InteriorOrRoomFeatures.HighCeilings_features: Estadístico F=2267.090, p-valor=0.000
# Levels.One_features: Estadístico F=2191.533, p-valor=0.000
# InteriorOrRoomFeatures.Chandelier_features: Estadístico F=2094.170, p-valor=0.000
# InteriorOrRoomFeatures.OpenFloorplan_features: Estadístico F=1825.627, p-valor=0.000
# Appliances.StainlessSteelAppliances_features: Estadístico F=1663.125, p-valor=0.000
# FireplaceFeatures.LivingRoom_features: Estadístico F=1524.729, p-valor=0.000
# InteriorOrRoomFeatures.BeamedCeilings_features: Estadístico F=1472.703, p-valor=0.000
# InteriorOrRoomFeatures.CrownMolding_features: Estadístico F=1385.933, p-valor=0.000
# WindowFeatures.Skylights_features: Estadístico F=1369.063, p-valor=0.000
# PatioAndPorchFeatures.Patio_features: Estadístico F=1349.731, p-valor=0.000
# OtherStructures.OutdoorKitchen_features: Estadístico F=1255.943, p-valor=0.000
# FireplaceFeatures.Bedroom_features: Estadístico F=1211.455, p-valor=0.000
# Levels.Two_features: Estadístico F=1118.209, p-valor=0.000
# ExteriorFeatures.Barbecue_features: Estadístico F=1051.075, p-valor=0.000
# ExteriorFeatures.OutdoorGrill_features: Estadístico F=1051.075, p-valor=0.000
# ExteriorFeatures.OutdoorKitchen_features: Estadístico F=1042.252, p-valor=0.000
# Appliances.RangeHood_features: Estadístico F=1010.934, p-valor=0.000
# ExteriorFeatures.BuiltInBarbecue_features: Estadístico F=985.861, p-valor=0.000
# ExteriorFeatures.FirePit_features: Estadístico F=902.165, p-valor=0.000
# FireplaceFeatures.FirePit_features: Estadístico F=902.165, p-valor=0.000
# Appliances.ElectricRange_features: Estadístico F=895.563, p-valor=0.000
# InteriorOrRoomFeatures.VaultedCeilings_features: Estadístico F=847.398, p-valor=0.000
# FireplaceFeatures.Outside_features: Estadístico F=830.750, p-valor=0.000
# LaundryFeatures.Sink_features: Estadístico F=825.726, p-valor=0.000
# Appliances.Range_features: Estadístico F=792.450, p-valor=0.000
# View.City_features: Estadístico F=735.897, p-valor=0.000
# ParkingFeatures.Detached_features: Estadístico F=714.260, p-valor=0.000
# OtherStructures.Garages_features: Estadístico F=713.833, p-valor=0.000
# LaundryFeatures.LaundryRoom_features: Estadístico F=688.293, p-valor=0.000
# InteriorOrRoomFeatures.WetBar_features: Estadístico F=624.555, p-valor=0.000
# InteriorOrRoomFeatures.WalkInClosets_features: Estadístico F=623.824, p-valor=0.000
# FireplaceFeatures.RaisedHearth_features: Estadístico F=599.626, p-valor=0.000
# View.Skyline_features: Estadístico F=569.291, p-valor=0.000
# FireplaceFeatures.GlassDoors_features: Estadístico F=532.828, p-valor=0.000
# OtherStructures.Pergola_features: Estadístico F=519.209, p-valor=0.000
# FireplaceFeatures.Stone_features: Estadístico F=497.091, p-valor=0.000
# View.Forest_features: Estadístico F=488.298, p-valor=0.000
# View.TreesWoods_features: Estadístico F=488.298, p-valor=0.000
# ExteriorFeatures.Balcony_features: Estadístico F=468.629, p-valor=0.000
# Appliances.WaterHeater_features: Estadístico F=456.393, p-valor=0.000
# SpaFeatures.InGround_features: Estadístico F=453.634, p-valor=0.000
# Appliances.TanklessWaterHeater_features: Estadístico F=453.323, p-valor=0.000
# SpaFeatures.Private_features: Estadístico F=420.956, p-valor=0.000
# PoolFeatures.PoolSpaCombo_features: Estadístico F=406.286, p-valor=0.000
# View.Water_features: Estadístico F=383.963, p-valor=0.000
# Appliances.GasWaterHeater_features: Estadístico F=378.771, p-valor=0.000
# FireplaceFeatures.Masonry_features: Estadístico F=376.963, p-valor=0.000
# InteriorOrRoomFeatures.Sauna_features: Estadístico F=356.613, p-valor=0.000
# Cooling.WallWindowUnits_features: Estadístico F=325.682, p-valor=0.000
# AssociationAmenities.Barbecue_features: Estadístico F=325.332, p-valor=0.000
# ParkingFeatures.Garage_features: Estadístico F=302.965, p-valor=0.000
# PatioAndPorchFeatures.Deck_features: Estadístico F=300.832, p-valor=0.000
# Flooring.Tile_features: Estadístico F=273.288, p-valor=0.000
# PoolFeatures.Indoor_features: Estadístico F=260.504, p-valor=0.000
# Flooring.Hardwood_features: Estadístico F=256.194, p-valor=0.000
# ExteriorFeatures.Storage_features: Estadístico F=249.314, p-valor=0.000
# OtherStructures.Storage_features: Estadístico F=249.314, p-valor=0.000
# OtherStructures.Sheds_features: Estadístico F=248.928, p-valor=0.000
# Heating.Central_features: Estadístico F=245.442, p-valor=0.000
# Heating.ForcedAir_features: Estadístico F=245.442, p-valor=0.000
# LaundryFeatures.CommonArea_features: Estadístico F=231.940, p-valor=0.000
# PoolFeatures.InGround_features: Estadístico F=220.632, p-valor=0.000
# InteriorOrRoomFeatures.Elevator_features: Estadístico F=207.526, p-valor=0.000
# Cooling.CentralAir_features: Estadístico F=205.863, p-valor=0.000
# AssociationAmenities.GameRoom_features: Estadístico F=203.071, p-valor=0.000
# SecurityFeatures.SmokeDetectors_features: Estadístico F=193.728, p-valor=0.000
# PoolFeatures.DivingBoard_features: Estadístico F=192.648, p-valor=0.000
# Cooling.WindowUnits_features: Estadístico F=190.330, p-valor=0.000
# AssociationAmenities.FitnessCenter_features: Estadístico F=184.747, p-valor=0.000
# CommunityFeatures.FitnessCenter_features: Estadístico F=178.353, p-valor=0.000
# Cooling.WallUnits_features: Estadístico F=161.296, p-valor=0.000
# FireplaceFeatures.DiningRoom_features: Estadístico F=154.221, p-valor=0.000
# LaundryFeatures.InBasement_features: Estadístico F=152.121, p-valor=0.000
# AssociationAmenities.Laundry_features: Estadístico F=145.536, p-valor=0.000
# AssociationAmenities.IndoorPool_features: Estadístico F=135.797, p-valor=0.000
# Heating.NaturalGas_features: Estadístico F=135.453, p-valor=0.000
# Appliances.Dishwasher_features: Estadístico F=134.387, p-valor=0.000
# Appliances.IceMaker_features: Estadístico F=127.495, p-valor=0.000
# InteriorOrRoomFeatures.Pantry_features: Estadístico F=117.227, p-valor=0.000
# Roof.Slate_features: Estadístico F=116.940, p-valor=0.000
# ExteriorFeatures.BasketballCourt_features: Estadístico F=112.523, p-valor=0.000
# View.Beach_features: Estadístico F=111.062, p-valor=0.000
# WaterfrontFeatures.BeachFront_features: Estadístico F=111.062, p-valor=0.000
# Appliances.ElectricCooktop_features: Estadístico F=110.815, p-valor=0.000
# CommunityFeatures.Suburban_features: Estadístico F=109.505, p-valor=0.000
# Heating.Baseboard_features: Estadístico F=102.141, p-valor=0.000
# Cooling.CeilingFans_features: Estadístico F=101.481, p-valor=0.000
# InteriorOrRoomFeatures.CeilingFans_features: Estadístico F=101.481, p-valor=0.000
# View.Pool_features: Estadístico F=100.816, p-valor=0.000
# AssociationAmenities.BilliardRoom_features: Estadístico F=98.048, p-valor=0.000
# Appliances.Dryer_features: Estadístico F=96.874, p-valor=0.000
# Appliances.Washer_features: Estadístico F=96.874, p-valor=0.000
# Appliances.ElectricWaterHeater_features: Estadístico F=93.412, p-valor=0.000
# InteriorOrRoomFeatures.Bidet_features: Estadístico F=87.831, p-valor=0.000
# InteriorOrRoomFeatures.SoakingTub_features: Estadístico F=83.554, p-valor=0.000
# ParkingFeatures.Carport_features: Estadístico F=81.950, p-valor=0.000
# SpaFeatures.AboveGround_features: Estadístico F=76.362, p-valor=0.000
# Flooring.Parquet_features: Estadístico F=72.087, p-valor=0.000
# PoolFeatures.Private_features: Estadístico F=68.285, p-valor=0.000
# ParkingFeatures.AttachedCarport_features: Estadístico F=63.627, p-valor=0.000
# Levels.OneAndOneHalf_features: Estadístico F=63.434, p-valor=0.000
# Unknown_features: Estadístico F=61.652, p-valor=0.000
# LaundryFeatures.Inside_features: Estadístico F=60.583, p-valor=0.000
# ExteriorFeatures.Playground_features: Estadístico F=56.837, p-valor=0.000
# Appliances.WasherDryer_features: Estadístico F=56.691, p-valor=0.000
# PoolFeatures.OutdoorPool_features: Estadístico F=56.371, p-valor=0.000
# FireplaceFeatures.DoubleSided_features: Estadístico F=55.196, p-valor=0.000
# FireplaceFeatures.SeeThrough_features: Estadístico F=55.196, p-valor=0.000
# LaundryFeatures.WasherHookup_features: Estadístico F=50.298, p-valor=0.000
# LaundryFeatures.InKitchen_features: Estadístico F=50.269, p-valor=0.000
# WaterfrontFeatures.Pond_features: Estadístico F=49.660, p-valor=0.000
# OtherStructures.Gazebo_features: Estadístico F=48.440, p-valor=0.000
# View.River_features: Estadístico F=48.227, p-valor=0.000
# Flooring.Carpet_features: Estadístico F=46.394, p-valor=0.000
# ParkingFeatures.Attached_features: Estadístico F=46.201, p-valor=0.000
# View.Bridges_features: Estadístico F=46.007, p-valor=0.000
# Flooring.Brick_features: Estadístico F=45.388, p-valor=0.000
# AssociationAmenities.GolfCourse_features: Estadístico F=45.370, p-valor=0.000
# CommunityFeatures.Golf_features: Estadístico F=45.370, p-valor=0.000
# Heating.Radiant_features: Estadístico F=42.276, p-valor=0.000
# Roof.Mansard_features: Estadístico F=40.315, p-valor=0.000
# LaundryFeatures.InBathroom_features: Estadístico F=38.962, p-valor=0.000
# Basement.Daylight_features: Estadístico F=37.632, p-valor=0.000
# Appliances.WarmingDrawer_features: Estadístico F=36.666, p-valor=0.000
# ExteriorFeatures.Dock_features: Estadístico F=32.001, p-valor=0.000
# InteriorOrRoomFeatures.TrackLighting_features: Estadístico F=31.692, p-valor=0.000
# PatioAndPorchFeatures.Enclosed_features: Estadístico F=30.385, p-valor=0.000
# LaundryFeatures.ElectricDryerHookup_features: Estadístico F=29.532, p-valor=0.000
# OtherStructures.Stables_features: Estadístico F=29.422, p-valor=0.000
# Fencing.FrontYard_features: Estadístico F=26.677, p-valor=0.000
# Appliances.GasRange_features: Estadístico F=24.187, p-valor=0.000
# ParkingFeatures.DetachedCarport_features: Estadístico F=23.722, p-valor=0.000
# View.Pond_features: Estadístico F=23.387, p-valor=0.000
# SecurityFeatures.FireSprinklerSystem_features: Estadístico F=22.798, p-valor=0.000
# SpaFeatures.Community_features: Estadístico F=21.878, p-valor=0.000
# PoolFeatures.Fenced_features: Estadístico F=21.151, p-valor=0.000
# View.GolfCourse_features: Estadístico F=18.738, p-valor=0.000
# InteriorOrRoomFeatures.RecessedLighting_features: Estadístico F=18.136, p-valor=0.000
# Appliances.WasherDryerStacked_features: Estadístico F=15.661, p-valor=0.000
# PoolFeatures.ScreenEnclosure_features: Estadístico F=14.639, p-valor=0.000
# AssociationAmenities.BasketballCourt_features: Estadístico F=14.108, p-valor=0.000
# Appliances.WaterSoftener_features: Estadístico F=12.716, p-valor=0.000
# SecurityFeatures.ClosedCircuitCameras_features: Estadístico F=12.679, p-valor=0.000
# Flooring.Concrete_features: Estadístico F=12.254, p-valor=0.000
# AssociationAmenities.Elevators_features: Estadístico F=12.168, p-valor=0.000
# ExteriorFeatures.TennisCourts_features: Estadístico F=12.129, p-valor=0.000
# OtherStructures.TennisCourts_features: Estadístico F=12.129, p-valor=0.000
# Levels.ThreeOrMore_features: Estadístico F=11.777, p-valor=0.001
# Appliances.Refrigerator_features: Estadístico F=11.535, p-valor=0.001
# PatioAndPorchFeatures.GlassEnclosed_features: Estadístico F=11.148, p-valor=0.001
# ParkingFeatures.GarageDoorOpener_features: Estadístico F=10.909, p-valor=0.001
# PatioAndPorchFeatures.Porch_features: Estadístico F=10.488, p-valor=0.001
# AssociationAmenities.Storage_features: Estadístico F=9.710, p-valor=0.002
# InteriorOrRoomFeatures.TileCounters_features: Estadístico F=9.023, p-valor=0.003
# Appliances.Microwave_features: Estadístico F=8.813, p-valor=0.003
# View.Mountains_features: Estadístico F=8.792, p-valor=0.003
# OtherStructures.Outbuilding_features: Estadístico F=8.694, p-valor=0.003
# SpaFeatures.Bath_features: Estadístico F=8.320, p-valor=0.004
# Basement.Finished_features: Estadístico F=8.045, p-valor=0.005
# ConstructionMaterials.ShakeSiding_features: Estadístico F=8.010, p-valor=0.005
# AssociationAmenities.Pool_features: Estadístico F=7.788, p-valor=0.005
# CommunityFeatures.Pool_features: Estadístico F=7.788, p-valor=0.005
# PoolFeatures.Association_features: Estadístico F=7.788, p-valor=0.005
# PoolFeatures.Community_features: Estadístico F=7.788, p-valor=0.005
# WaterfrontFeatures.Creek_features: Estadístico F=7.177, p-valor=0.007
# OtherStructures.Workshop_features: Estadístico F=6.956, p-valor=0.008
# Heating.Propane_features: Estadístico F=6.694, p-valor=0.010
# Heating.SpaceHeater_features: Estadístico F=6.621, p-valor=0.010
# PoolFeatures.AboveGround_features: Estadístico F=6.417, p-valor=0.011
# SecurityFeatures.FireAlarm_features: Estadístico F=5.493, p-valor=0.019
# AssociationAmenities.SpaHotTub_features: Estadístico F=5.250, p-valor=0.022
# InteriorOrRoomFeatures.CathedralCeilings_features: Estadístico F=5.107, p-valor=0.024
# ExteriorFeatures.Garden_features: Estadístico F=5.051, p-valor=0.025
# Heating.Oil_features: Estadístico F=5.048, p-valor=0.025
# LaundryFeatures.InGarage_features: Estadístico F=4.703, p-valor=0.030
# PowerProductionType.Photovoltaics_features: Estadístico F=4.635, p-valor=0.031
# Appliances.BarFridge_features: Estadístico F=4.612, p-valor=0.032
# Basement.Block_features: Estadístico F=3.711, p-valor=0.054
# FoundationDetails.Block_features: Estadístico F=3.711, p-valor=0.054
# LaundryFeatures.GasDryerHookup_features: Estadístico F=3.154, p-valor=0.076
# ExteriorFeatures.Awnings_features: Estadístico F=2.938, p-valor=0.087
# AssociationAmenities.Park_features: Estadístico F=2.924, p-valor=0.087
# CommunityFeatures.Park_features: Estadístico F=2.924, p-valor=0.087
# Basement.CrawlSpace_features: Estadístico F=2.549, p-valor=0.110
# View.CreekStream_features: Estadístico F=2.259, p-valor=0.133
# ConstructionMaterials.Stone_features: Estadístico F=2.190, p-valor=0.139
# Roof.Metal_features: Estadístico F=2.066, p-valor=0.151
# Fencing.BackYard_features: Estadístico F=1.968, p-valor=0.161
# AssociationAmenities.ShuffleboardCourt_features: Estadístico F=1.683, p-valor=0.195
# OtherEquipment.SatelliteDish_features: Estadístico F=1.549, p-valor=0.213
# Flooring.Stone_features: Estadístico F=1.415, p-valor=0.234
# Heating.Ductless_features: Estadístico F=1.377, p-valor=0.241
# Heating.WoodStove_features: Estadístico F=1.351, p-valor=0.245
# AssociationAmenities.DogPark_features: Estadístico F=1.312, p-valor=0.252
# ConstructionMaterials.Brick_features: Estadístico F=1.284, p-valor=0.257
# Heating.Electric_features: Estadístico F=1.192, p-valor=0.275
# CommunityFeatures.Lake_features: Estadístico F=1.116, p-valor=0.291
# WaterfrontFeatures.Lake_features: Estadístico F=1.116, p-valor=0.291
# Flooring.Wood_features: Estadístico F=1.083, p-valor=0.298
# Basement.Unfinished_features: Estadístico F=1.066, p-valor=0.302
# ExteriorFeatures.PrivateYard_features: Estadístico F=1.043, p-valor=0.307
# Fencing.Fenced_features: Estadístico F=1.043, p-valor=0.307
# Cooling.Ductless_features: Estadístico F=0.924, p-valor=0.336
# CommunityFeatures.TennisCourts_features: Estadístico F=0.917, p-valor=0.338
# PatioAndPorchFeatures.FrontPorch_features: Estadístico F=0.849, p-valor=0.357
# LaundryFeatures.LaundryCloset_features: Estadístico F=0.835, p-valor=0.361
# FireplaceFeatures.Basement_features: Estadístico F=0.743, p-valor=0.389
# ParkingFeatures.ParkingPad_features: Estadístico F=0.726, p-valor=0.394
# InteriorOrRoomFeatures.HisAndHersClosets_features: Estadístico F=0.679, p-valor=0.410
# AssociationAmenities.TennisCourts_features: Estadístico F=0.628, p-valor=0.428
# ParkingFeatures.Basement_features: Estadístico F=0.623, p-valor=0.430
# Appliances.TrashCompactor_features: Estadístico F=0.621, p-valor=0.431
# Roof.Wood_features: Estadístico F=0.606, p-valor=0.436
# Levels.MultiSplit_features: Estadístico F=0.594, p-valor=0.441
# AssociationAmenities.SportCourt_features: Estadístico F=0.583, p-valor=0.445
# AssociationAmenities.Playground_features: Estadístico F=0.543, p-valor=0.461
# CommunityFeatures.Playground_features: Estadístico F=0.543, p-valor=0.461
# ParkingFeatures.WorkshopInGarage_features: Estadístico F=0.527, p-valor=0.468
# Basement.WalkOutAccess_features: Estadístico F=0.518, p-valor=0.472
# Basement.ExteriorEntry_features: Estadístico F=0.487, p-valor=0.485
# Heating.WallFurnace_features: Estadístico F=0.460, p-valor=0.497
# Roof.Shingle_features: Estadístico F=0.382, p-valor=0.536
# AssociationAmenities.Marina_features: Estadístico F=0.376, p-valor=0.540
# CommunityFeatures.Sidewalks_features: Estadístico F=0.346, p-valor=0.557
# ParkingFeatures.ParkingLot_features: Estadístico F=0.326, p-valor=0.568
# ParkingFeatures.Driveway_features: Estadístico F=0.319, p-valor=0.572
# View.Marina_features: Estadístico F=0.310, p-valor=0.578
# ParkingFeatures.ElectricVehicleChargingStations_features: Estadístico F=0.291, p-valor=0.590
# OtherStructures.RvBoatStorage_features: Estadístico F=0.281, p-valor=0.596
# ParkingFeatures.RvGarage_features: Estadístico F=0.281, p-valor=0.596
# View.Neighborhood_features: Estadístico F=0.279, p-valor=0.597
# ConstructionMaterials.VerticalSiding_features: Estadístico F=0.274, p-valor=0.601
# Electric.Generator_features: Estadístico F=0.261, p-valor=0.610
# PoolFeatures.PoolCover_features: Estadístico F=0.254, p-valor=0.614
# FrontageType.Waterfront_features: Estadístico F=0.241, p-valor=0.623
# WaterfrontFeatures.Waterfront_features: Estadístico F=0.241, p-valor=0.623
# AssociationAmenities.Parking_features: Estadístico F=0.224, p-valor=0.636
# ParkingFeatures.CommunityStructure_features: Estadístico F=0.224, p-valor=0.636
# ParkingFeatures.Deck_features: Estadístico F=0.224, p-valor=0.636
# View.Rural_features: Estadístico F=0.200, p-valor=0.655
# OtherEquipment.Dehumidifier_features: Estadístico F=0.199, p-valor=0.655
# InteriorOrRoomFeatures.CentralVacuum_features: Estadístico F=0.136, p-valor=0.713
# View.ParkGreenbelt_features: Estadístico F=0.106, p-valor=0.744
# Flooring.Terrazzo_features: Estadístico F=0.094, p-valor=0.760
# Basement.SumpPump_features: Estadístico F=0.089, p-valor=0.766
# Basement.PartiallyFinished_features: Estadístico F=0.084, p-valor=0.772
# View.Lake_features: Estadístico F=0.075, p-valor=0.785
# ConstructionMaterials.Stucco_features: Estadístico F=0.063, p-valor=0.801
# InteriorOrRoomFeatures.DryBar_features: Estadístico F=0.042, p-valor=0.837
# Basement.InteriorEntry_features: Estadístico F=0.041, p-valor=0.840
# Flooring.Granite_features: Estadístico F=0.035, p-valor=0.852
# Roof.Tile_features: Estadístico F=0.034, p-valor=0.854
# AssociationAmenities.Racquetball_features: Estadístico F=0.030, p-valor=0.862
# CommunityFeatures.Racquetball_features: Estadístico F=0.030, p-valor=0.862
# ConstructionMaterials.WoodSiding_features: Estadístico F=0.022, p-valor=0.883
# CommunityFeatures.Curbs_features: Estadístico F=0.017, p-valor=0.895
# InteriorOrRoomFeatures.Bookcases_features: Estadístico F=0.015, p-valor=0.902
# Basement.Concrete_features: Estadístico F=0.013, p-valor=0.909
# ExteriorFeatures.RainGutters_features: Estadístico F=0.013, p-valor=0.911
# View.Ocean_features: Estadístico F=0.010, p-valor=0.922
# Basement.StorageSpace_features: Estadístico F=0.008, p-valor=0.927
# Flooring.Vinyl_features: Estadístico F=0.003, p-valor=0.953
# ConstructionMaterials.BoardAndBattenSiding_features: Estadístico F=0.002, p-valor=0.963
# Heating.HotWater_features: Estadístico F=0.001, p-valor=0.972
# LaundryFeatures.Outside_features: Estadístico F=0.001, p-valor=0.975
#
# Características importantes (p-valor < 0.05): ['Appliances.BarFridge_features', 'Appliances.BuiltInRefrigerator_features', 'Appliances.Cooktop_features', 'Appliances.Dishwasher_features', 'Appliances.DoubleOven_features', 'Appliances.Dryer_features', 'Appliances.ElectricCooktop_features', 'Appliances.ElectricRange_features', 'Appliances.ElectricWaterHeater_features', 'Appliances.GasCooktop_features', 'Appliances.GasRange_features', 'Appliances.GasWaterHeater_features', 'Appliances.IceMaker_features', 'Appliances.Microwave_features', 'Appliances.Oven_features', 'Appliances.Range_features', 'Appliances.RangeHood_features', 'Appliances.Refrigerator_features', 'Appliances.StainlessSteelAppliances_features', 'Appliances.TanklessWaterHeater_features', 'Appliances.WarmingDrawer_features', 'Appliances.Washer_features', 'Appliances.WasherDryer_features', 'Appliances.WasherDryerStacked_features', 'Appliances.WaterHeater_features', 'Appliances.WaterSoftener_features', 'Appliances.WineCooler_features', 'AssociationAmenities.Barbecue_features', 'AssociationAmenities.BasketballCourt_features', 'AssociationAmenities.BilliardRoom_features', 'AssociationAmenities.Elevators_features', 'AssociationAmenities.FitnessCenter_features', 'AssociationAmenities.GameRoom_features', 'AssociationAmenities.GolfCourse_features', 'AssociationAmenities.IndoorPool_features', 'AssociationAmenities.Laundry_features', 'AssociationAmenities.Pool_features', 'AssociationAmenities.SpaHotTub_features', 'AssociationAmenities.Storage_features', 'Basement.Daylight_features', 'Basement.Finished_features', 'CommunityFeatures.FitnessCenter_features', 'CommunityFeatures.Golf_features', 'CommunityFeatures.Pool_features', 'CommunityFeatures.Suburban_features', 'ConstructionMaterials.ShakeSiding_features', 'Cooling.CeilingFans_features', 'Cooling.CentralAir_features', 'Cooling.WallUnits_features', 'Cooling.WallWindowUnits_features', 'Cooling.WindowUnits_features', 'DoorFeatures.FrenchDoors_features', 'ExteriorFeatures.Balcony_features', 'ExteriorFeatures.Barbecue_features', 'ExteriorFeatures.BasketballCourt_features', 'ExteriorFeatures.BuiltInBarbecue_features', 'ExteriorFeatures.Dock_features', 'ExteriorFeatures.FirePit_features', 'ExteriorFeatures.Garden_features', 'ExteriorFeatures.OutdoorGrill_features', 'ExteriorFeatures.OutdoorKitchen_features', 'ExteriorFeatures.Playground_features', 'ExteriorFeatures.Storage_features', 'ExteriorFeatures.TennisCourts_features', 'Fencing.FrontYard_features', 'FireplaceFeatures.Bedroom_features', 'FireplaceFeatures.DiningRoom_features', 'FireplaceFeatures.DoubleSided_features', 'FireplaceFeatures.FirePit_features', 'FireplaceFeatures.GlassDoors_features', 'FireplaceFeatures.LivingRoom_features', 'FireplaceFeatures.Masonry_features', 'FireplaceFeatures.Outside_features', 'FireplaceFeatures.RaisedHearth_features', 'FireplaceFeatures.SeeThrough_features', 'FireplaceFeatures.Stone_features', 'Flooring.Brick_features', 'Flooring.Carpet_features', 'Flooring.Concrete_features', 'Flooring.Hardwood_features', 'Flooring.Parquet_features', 'Flooring.Tile_features', 'Heating.Baseboard_features', 'Heating.Central_features', 'Heating.Fireplaces_features', 'Heating.ForcedAir_features', 'Heating.NaturalGas_features', 'Heating.Oil_features', 'Heating.Propane_features', 'Heating.Radiant_features', 'Heating.SpaceHeater_features', 'InteriorOrRoomFeatures.Bar_features', 'InteriorOrRoomFeatures.BeamedCeilings_features', 'InteriorOrRoomFeatures.Bidet_features', 'InteriorOrRoomFeatures.BreakfastBar_features', 'InteriorOrRoomFeatures.BuiltInFeatures_features', 'InteriorOrRoomFeatures.CathedralCeilings_features', 'InteriorOrRoomFeatures.CeilingFans_features', 'InteriorOrRoomFeatures.Chandelier_features', 'InteriorOrRoomFeatures.CofferedCeilings_features', 'InteriorOrRoomFeatures.CrownMolding_features', 'InteriorOrRoomFeatures.DoubleVanity_features', 'InteriorOrRoomFeatures.Elevator_features', 'InteriorOrRoomFeatures.HighCeilings_features', 'InteriorOrRoomFeatures.Ki ...

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales en el conjunto de validación
valid['ImageData.features_reso.results'] = valid['ImageData.features_reso.results'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer entrenado en el conjunto de entrenamiento para transformar las listas en variables binarias
# Se asume que 'mlb' es el MultiLabelBinarizer que fue entrenado con 'train'
binary_features_valid = mlb.transform(valid['ImageData.features_reso.results'])
binary_df_valid = pd.DataFrame(binary_features_valid, columns=mlb.classes_, index=valid.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame de validación
valid = pd.concat([valid, binary_df_valid], axis=1)

# Mostrar el DataFrame actualizado de validación con las nuevas características binarias
print(valid.head())
# Out:
#                              Characteristics.LotFeatures  \
# 32045                                                NaN
# 64911                                                NaN
# 60627  ['pond(s)', 'water view', 'sidewalks', 'street...
# 97370                                                NaN
# 2323                                                 NaN
#
#        ImageData.c1c6.summary.exterior  \
# 32045                          3.06213
# 64911                          3.50000
# 60627                          3.00000
# 97370                          4.00000
# 2323                           1.00000
#
#                          ImageData.features_reso.results  \
# 32045  [Appliances.Dishwasher, Appliances.ElectricRan...
# 64911  [Appliances.GasRange, Appliances.Range, Applia...
# 60627  [Appliances.Dishwasher, Appliances.GasRange, A...
# 97370  [Appliances.Dishwasher, Appliances.Refrigerato...
# 2323   [Appliances.Dishwasher, Appliances.Microwave, ...
#
#        ImageData.q1q6.summary.exterior  \
# 32045                         3.295942
# 64911                         4.200000
# 60627                         3.700000
# 97370                         3.900000
# 2323                          3.600000
#
#                         ImageData.room_type_reso.results  \
# 32045  ['Bathroom', 'Kitchen', 'Other', 'Hallway', 'L...
# 64911  ['FrontOfStructure', 'Other', 'Bedroom', 'Kitc...
# 60627  ['FrontOfStructure', 'Other', 'Entry', 'Kitche...
# 97370  ['FrontOfStructure', 'LivingRoom', 'Kitchen', ...
# 2323   ['FrontOfStructure', 'EntranceFoyer', 'Other',...
#
#       ImageData.style.exterior.summary.label  \
# 32045                                Unknown
# 64911                                  ranch
# 60627                            traditional
# 97370                               bungalow
# 2323                                   ranch
#
#        ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 32045                                    1.0     2023-10-26T00:00:00
# 64911                                    1.0     2024-01-08T00:00:00
# 60627                                    2.0     2024-02-02T00:00:00
# 97370                                    1.0     2024-05-29T00:00:00
# 2323                                     1.0     2023-11-21T00:00:00
#
#       Listing.ListingId  Listing.Price.ClosePrice  ... View.Rural  \
# 32045       mrd11852720                  138000.0  ...          0
# 64911       mrd11938750                  290000.0  ...          0
# 60627       mrd11927754                  325000.0  ...          0
# 97370       mrd12024781                  300000.0  ...          0
# 2323        mrd11728531                  312212.0  ...          0
#
#       View.Skyline View.TreesWoods View.Water WaterfrontFeatures.BeachFront  \
# 32045            0               0          1                             0
# 64911            0               0          0                             0
# 60627            0               0          0                             0
# 97370            0               0          0                             0
# 2323             0               0          0                             0
#
#       WaterfrontFeatures.Creek WaterfrontFeatures.Lake  \
# 32045                        0                       0
# 64911                        0                       0
# 60627                        0                       0
# 97370                        0                       0
# 2323                         0                       0
#
#       WaterfrontFeatures.Pond WaterfrontFeatures.Waterfront  \
# 32045                       0                             0
# 64911                       0                             0
# 60627                       0                             0
# 97370                       0                             0
# 2323                        0                             0
#
#        WindowFeatures.Skylights
# 32045                         0
# 64911                         0
# 60627                         0
# 97370                         0
# 2323                          0
#
# [5 rows x 337 columns]

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import spearmanr
from scipy.stats import f_oneway

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales
# Si hay valores NaN, los reemplazamos con ['Unknown']
train['Characteristics.LotFeatures'] = train['Characteristics.LotFeatures'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer para transformar las listas en variables binarias
mlb = MultiLabelBinarizer()
binary_features = mlb.fit_transform(train['Characteristics.LotFeatures'])
binary_df = pd.DataFrame(binary_features, columns=mlb.classes_, index=train.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame original
binary_df.columns = [col + '_characteristic' for col in binary_df.columns]
df = pd.concat([train, binary_df], axis=1)

# Paso 4: Realizar ANOVA para cada variable binarizada
anova_results = {}
for column in binary_df.columns:
    # Dividir la variable continua en grupos según la variable binaria
    group_0 = df[df[column] == 0]['Listing.Price.ClosePrice']
    group_1 = df[df[column] == 1]['Listing.Price.ClosePrice']
    
    # Calcular ANOVA
    if len(group_0) > 1 and len(group_1) > 1:  # Asegurarse de que hay suficientes datos en ambos grupos
        f_stat, p_value = f_oneway(group_0, group_1)
        anova_results[column] = (f_stat, p_value)
    else:
        anova_results[column] = (None, None)  # Insuficientes datos para el ANOVA

# Paso 5: Ordenar los resultados por el estadístico F
sorted_anova = sorted(anova_results.items(), key=lambda x: x[1][0] if x[1][0] is not None else 0, reverse=True)

# Paso 6: Filtrar características importantes según p-valor
threshold_p_value = 0.05
important_features = [feature for feature, (f_stat, p_value) in anova_results.items() if p_value is not None and p_value < threshold_p_value]

# Mostrar resultados
print("Resultados de ANOVA ordenados (por estadístico F):")
for feature, (f_stat, p_value) in sorted_anova:
    if f_stat is not None:
        print(f"{feature}: Estadístico F={f_stat:.3f}, p-valor={p_value:.3f}")

print("\nCaracterísticas importantes (p-valor < 0.05):", important_features)

significant_binary_df = binary_df[important_features]
train = pd.concat([train, significant_binary_df], axis=1)
# Out:
# Resultados de ANOVA ordenados (por estadístico F):
# landscaped_characteristic: Estadístico F=1776.998, p-valor=0.000
# Unknown_characteristic: Estadístico F=517.760, p-valor=0.000
# outdoor lighting_characteristic: Estadístico F=409.883, p-valor=0.000
# mature trees_characteristic: Estadístico F=341.788, p-valor=0.000
# wooded_characteristic: Estadístico F=293.684, p-valor=0.000
# cul-de-sac_characteristic: Estadístico F=278.130, p-valor=0.000
# water view_characteristic: Estadístico F=194.392, p-valor=0.000
# lake front_characteristic: Estadístico F=163.086, p-valor=0.000
# beach_characteristic: Estadístico F=159.081, p-valor=0.000
# common grounds_characteristic: Estadístico F=155.106, p-valor=0.000
# horses allowed_characteristic: Estadístico F=137.428, p-valor=0.000
# waterfront_characteristic: Estadístico F=100.232, p-valor=0.000
# fenced yard_characteristic: Estadístico F=89.390, p-valor=0.000
# lake access_characteristic: Estadístico F=85.743, p-valor=0.000
# golf course lot_characteristic: Estadístico F=84.112, p-valor=0.000
# garden_characteristic: Estadístico F=68.978, p-valor=0.000
# irregular lot_characteristic: Estadístico F=66.768, p-valor=0.000
# pond(s)_characteristic: Estadístico F=62.377, p-valor=0.000
# park adjacent_characteristic: Estadístico F=56.386, p-valor=0.000
# paddock_characteristic: Estadístico F=47.632, p-valor=0.000
# sidewalks_characteristic: Estadístico F=43.525, p-valor=0.000
# fence-invisible pet_characteristic: Estadístico F=42.017, p-valor=0.000
# corner lot_characteristic: Estadístico F=40.892, p-valor=0.000
# views_characteristic: Estadístico F=38.604, p-valor=0.000
# forest preserve adjacent_characteristic: Estadístico F=37.837, p-valor=0.000
# nature preserve adjacent_characteristic: Estadístico F=33.037, p-valor=0.000
# river front_characteristic: Estadístico F=31.254, p-valor=0.000
# pasture_characteristic: Estadístico F=22.064, p-valor=0.000
# dock_characteristic: Estadístico F=21.656, p-valor=0.000
# stream(s)_characteristic: Estadístico F=20.392, p-valor=0.000
# water garden_characteristic: Estadístico F=18.069, p-valor=0.000
# wood fence_characteristic: Estadístico F=16.885, p-valor=0.000
# backs to trees/woods_characteristic: Estadístico F=16.249, p-valor=0.000
# chain link fence_characteristic: Estadístico F=12.690, p-valor=0.000
# streetlights_characteristic: Estadístico F=12.568, p-valor=0.000
# creek_characteristic: Estadístico F=11.535, p-valor=0.001
# partial fencing_characteristic: Estadístico F=10.496, p-valor=0.001
# none_characteristic: Estadístico F=8.343, p-valor=0.004
# water rights_characteristic: Estadístico F=7.474, p-valor=0.006
# pie shaped lot_characteristic: Estadístico F=7.365, p-valor=0.007
# electric fence_characteristic: Estadístico F=4.395, p-valor=0.036
# chain of lakes frontage_characteristic: Estadístico F=4.357, p-valor=0.037
# wetlands adjacent_characteristic: Estadístico F=3.367, p-valor=0.067
# sloped_characteristic: Estadístico F=1.934, p-valor=0.164
# spring(s)_characteristic: Estadístico F=1.932, p-valor=0.165
# rear of lot_characteristic: Estadístico F=0.932, p-valor=0.334
# channel front_characteristic: Estadístico F=0.848, p-valor=0.357
# other_characteristic: Estadístico F=0.738, p-valor=0.390
# dimensions to center of road_characteristic: Estadístico F=0.460, p-valor=0.497
# woven wire fence_characteristic: Estadístico F=0.297, p-valor=0.586
# legal non-conforming_characteristic: Estadístico F=0.157, p-valor=0.692
# backs to open grnd_characteristic: Estadístico F=0.066, p-valor=0.797
# backs to public grnd_characteristic: Estadístico F=0.051, p-valor=0.821
# adjoins government land_characteristic: Estadístico F=0.031, p-valor=0.860
# level_characteristic: Estadístico F=0.003, p-valor=0.957
#
# Características importantes (p-valor < 0.05): ['Unknown_characteristic', 'backs to trees/woods_characteristic', 'beach_characteristic', 'chain link fence_characteristic', 'chain of lakes frontage_characteristic', 'common grounds_characteristic', 'corner lot_characteristic', 'creek_characteristic', 'cul-de-sac_characteristic', 'dock_characteristic', 'electric fence_characteristic', 'fence-invisible pet_characteristic', 'fenced yard_characteristic', 'forest preserve adjacent_characteristic', 'garden_characteristic', 'golf course lot_characteristic', 'horses allowed_characteristic', 'irregular lot_characteristic', 'lake access_characteristic', 'lake front_characteristic', 'landscaped_characteristic', 'mature trees_characteristic', 'nature preserve adjacent_characteristic', 'none_characteristic', 'outdoor lighting_characteristic', 'paddock_characteristic', 'park adjacent_characteristic', 'partial fencing_characteristic', 'pasture_characteristic', 'pie shaped lot_characteristic', 'pond(s)_characteristic', 'river front_characteristic', 'sidewalks_characteristic', 'stream(s)_characteristic', 'streetlights_characteristic', 'views_characteristic', 'water garden_characteristic', 'water rights_characteristic', 'water view_characteristic', 'waterfront_characteristic', 'wood fence_characteristic', 'wooded_characteristic']

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales en el conjunto de validación
valid['Characteristics.LotFeatures'] = valid['Characteristics.LotFeatures'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer entrenado con el conjunto de entrenamiento
# Utilizamos el `mlb` entrenado previamente en el conjunto de `train`
binary_features_valid = mlb.transform(valid['Characteristics.LotFeatures'])
binary_df_valid = pd.DataFrame(binary_features_valid, columns=mlb.classes_, index=valid.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame de validación
binary_df_valid.columns = [col + '_characteristic' for col in binary_df_valid.columns]
valid = pd.concat([valid, binary_df_valid], axis=1)

# Mostrar el DataFrame actualizado de validación con las nuevas características binarias
print(valid.head())
# Out:
#                           Characteristics.LotFeatures  \
# 32045                                       [Unknown]
# 64911                                       [Unknown]
# 60627  [pond(s), water view, sidewalks, streetlights]
# 97370                                       [Unknown]
# 2323                                        [Unknown]
#
#        ImageData.c1c6.summary.exterior  \
# 32045                          3.06213
# 64911                          3.50000
# 60627                          3.00000
# 97370                          4.00000
# 2323                           1.00000
#
#                          ImageData.features_reso.results  \
# 32045  [Appliances.Dishwasher, Appliances.ElectricRan...
# 64911  [Appliances.GasRange, Appliances.Range, Applia...
# 60627  [Appliances.Dishwasher, Appliances.GasRange, A...
# 97370  [Appliances.Dishwasher, Appliances.Refrigerato...
# 2323   [Appliances.Dishwasher, Appliances.Microwave, ...
#
#        ImageData.q1q6.summary.exterior  \
# 32045                         3.295942
# 64911                         4.200000
# 60627                         3.700000
# 97370                         3.900000
# 2323                          3.600000
#
#                         ImageData.room_type_reso.results  \
# 32045  ['Bathroom', 'Kitchen', 'Other', 'Hallway', 'L...
# 64911  ['FrontOfStructure', 'Other', 'Bedroom', 'Kitc...
# 60627  ['FrontOfStructure', 'Other', 'Entry', 'Kitche...
# 97370  ['FrontOfStructure', 'LivingRoom', 'Kitchen', ...
# 2323   ['FrontOfStructure', 'EntranceFoyer', 'Other',...
#
#       ImageData.style.exterior.summary.label  \
# 32045                                Unknown
# 64911                                  ranch
# 60627                            traditional
# 97370                               bungalow
# 2323                                   ranch
#
#        ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 32045                                    1.0     2023-10-26T00:00:00
# 64911                                    1.0     2024-01-08T00:00:00
# 60627                                    2.0     2024-02-02T00:00:00
# 97370                                    1.0     2024-05-29T00:00:00
# 2323                                     1.0     2023-11-21T00:00:00
#
#       Listing.ListingId  Listing.Price.ClosePrice  ...  \
# 32045       mrd11852720                  138000.0  ...
# 64911       mrd11938750                  290000.0  ...
# 60627       mrd11927754                  325000.0  ...
# 97370       mrd12024781                  300000.0  ...
# 2323        mrd11728531                  312212.0  ...
#
#       streetlights_characteristic views_characteristic  \
# 32045                           0                    0
# 64911                           0                    0
# 60627                           1                    0
# 97370                           0                    0
# 2323                            0                    0
#
#       water garden_characteristic water rights_characteristic  \
# 32045                           0                           0
# 64911                           0                           0
# 60627                           0                           0
# 97370                           0                           0
# 2323                            0                           0
#
#       water view_characteristic waterfront_characteristic  \
# 32045                         0                         0
# 64911                         0                         0
# 60627                         1                         0
# 97370                         0                         0
# 2323                          0                         0
#
#       wetlands adjacent_characteristic wood fence_characteristic  \
# 32045                                0                         0
# 64911                                0                         0
# 60627                                0                         0
# 97370                                0                         0
# 2323                                 0                         0
#
#       wooded_characteristic  woven wire fence_characteristic
# 32045                     0                                0
# 64911                     0                                0
# 60627                     0                                0
# 97370                     0                                0
# 2323                      0                                0
#
# [5 rows x 393 columns]

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import spearmanr

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales
# Si hay valores NaN, los reemplazamos con ['Unknown']
train['Structure.Cooling'] = train['Structure.Cooling'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer para transformar las listas en variables binarias
mlb = MultiLabelBinarizer()
binary_features = mlb.fit_transform(train['Structure.Cooling'])
binary_df = pd.DataFrame(binary_features, columns=mlb.classes_, index=train.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame original
binary_df.columns = [col + '_cooling' for col in binary_df.columns]
df = pd.concat([train, binary_df], axis=1)

# Paso 4: Realizar ANOVA para cada variable binarizada
anova_results = {}
for column in binary_df.columns:
    # Dividir la variable continua en grupos según la variable binaria
    group_0 = df[df[column] == 0]['Listing.Price.ClosePrice']
    group_1 = df[df[column] == 1]['Listing.Price.ClosePrice']
    
    # Calcular ANOVA
    if len(group_0) > 1 and len(group_1) > 1:  # Asegurarse de que hay suficientes datos en ambos grupos
        f_stat, p_value = f_oneway(group_0, group_1)
        anova_results[column] = (f_stat, p_value)
    else:
        anova_results[column] = (None, None)  # Insuficientes datos para el ANOVA

# Paso 5: Ordenar los resultados por el estadístico F
sorted_anova = sorted(anova_results.items(), key=lambda x: x[1][0] if x[1][0] is not None else 0, reverse=True)

# Paso 6: Filtrar características importantes según p-valor
threshold_p_value = 0.05
important_features = [feature for feature, (f_stat, p_value) in anova_results.items() if p_value is not None and p_value < threshold_p_value]

# Mostrar resultados
print("Resultados de ANOVA ordenados (por estadístico F):")
for feature, (f_stat, p_value) in sorted_anova:
    if f_stat is not None:
        print(f"{feature}: Estadístico F={f_stat:.3f}, p-valor={p_value:.3f}")

print("\nCaracterísticas importantes (p-valor < 0.05):", important_features)

significant_binary_df = binary_df[important_features]
train = pd.concat([train, significant_binary_df], axis=1)
# Out:
# Resultados de ANOVA ordenados (por estadístico F):
# zoned_cooling: Estadístico F=9452.232, p-valor=0.000
# none_cooling: Estadístico F=1343.623, p-valor=0.000
# central air_cooling: Estadístico F=1180.513, p-valor=0.000
# space pac_cooling: Estadístico F=939.757, p-valor=0.000
# window/wall unit - 1_cooling: Estadístico F=738.796, p-valor=0.000
# window/wall units - 2_cooling: Estadístico F=511.205, p-valor=0.000
# office only_cooling: Estadístico F=103.947, p-valor=0.000
# dual_cooling: Estadístico F=96.869, p-valor=0.000
# central individual_cooling: Estadístico F=90.263, p-valor=0.000
# geothermal_cooling: Estadístico F=71.052, p-valor=0.000
# partial_cooling: Estadístico F=68.916, p-valor=0.000
# wall sleeve_cooling: Estadístico F=51.258, p-valor=0.000
# window unit(s)_cooling: Estadístico F=49.365, p-valor=0.000
# other_cooling: Estadístico F=38.410, p-valor=0.000
# window/wall units - 3+_cooling: Estadístico F=37.940, p-valor=0.000
# power roof vents_cooling: Estadístico F=34.183, p-valor=0.000
# Unknown_cooling: Estadístico F=32.881, p-valor=0.000
# gas_cooling: Estadístico F=19.643, p-valor=0.000
# electric_cooling: Estadístico F=17.975, p-valor=0.000
# chillers_cooling: Estadístico F=13.726, p-valor=0.000
# ceiling fan(s)_cooling: Estadístico F=9.025, p-valor=0.003
# high efficiency (seer 14+)_cooling: Estadístico F=6.690, p-valor=0.010
# roof turbine(s)_cooling: Estadístico F=0.618, p-valor=0.432
# exhaust fan_cooling: Estadístico F=0.044, p-valor=0.834
#
# Características importantes (p-valor < 0.05): ['Unknown_cooling', 'ceiling fan(s)_cooling', 'central air_cooling', 'central individual_cooling', 'chillers_cooling', 'dual_cooling', 'electric_cooling', 'gas_cooling', 'geothermal_cooling', 'high efficiency (seer 14+)_cooling', 'none_cooling', 'office only_cooling', 'other_cooling', 'partial_cooling', 'power roof vents_cooling', 'space pac_cooling', 'wall sleeve_cooling', 'window unit(s)_cooling', 'window/wall unit - 1_cooling', 'window/wall units - 2_cooling', 'window/wall units - 3+_cooling', 'zoned_cooling']

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales en el conjunto de validación
valid['Structure.Cooling'] = valid['Structure.Cooling'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer entrenado con el conjunto de entrenamiento
# Utilizamos el `mlb` entrenado previamente en el conjunto de `train`
binary_features_valid = mlb.transform(valid['Structure.Cooling'])
binary_df_valid = pd.DataFrame(binary_features_valid, columns=mlb.classes_, index=valid.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame de validación
binary_df_valid.columns = [col + '_cooling' for col in binary_df_valid.columns]
valid = pd.concat([valid, binary_df_valid], axis=1)

# Mostrar el DataFrame actualizado de validación con las nuevas características binarias
print(valid.head())
# Out:
#                           Characteristics.LotFeatures  \
# 32045                                       [Unknown]
# 64911                                       [Unknown]
# 60627  [pond(s), water view, sidewalks, streetlights]
# 97370                                       [Unknown]
# 2323                                        [Unknown]
#
#        ImageData.c1c6.summary.exterior  \
# 32045                          3.06213
# 64911                          3.50000
# 60627                          3.00000
# 97370                          4.00000
# 2323                           1.00000
#
#                          ImageData.features_reso.results  \
# 32045  [Appliances.Dishwasher, Appliances.ElectricRan...
# 64911  [Appliances.GasRange, Appliances.Range, Applia...
# 60627  [Appliances.Dishwasher, Appliances.GasRange, A...
# 97370  [Appliances.Dishwasher, Appliances.Refrigerato...
# 2323   [Appliances.Dishwasher, Appliances.Microwave, ...
#
#        ImageData.q1q6.summary.exterior  \
# 32045                         3.295942
# 64911                         4.200000
# 60627                         3.700000
# 97370                         3.900000
# 2323                          3.600000
#
#                         ImageData.room_type_reso.results  \
# 32045  ['Bathroom', 'Kitchen', 'Other', 'Hallway', 'L...
# 64911  ['FrontOfStructure', 'Other', 'Bedroom', 'Kitc...
# 60627  ['FrontOfStructure', 'Other', 'Entry', 'Kitche...
# 97370  ['FrontOfStructure', 'LivingRoom', 'Kitchen', ...
# 2323   ['FrontOfStructure', 'EntranceFoyer', 'Other',...
#
#       ImageData.style.exterior.summary.label  \
# 32045                                Unknown
# 64911                                  ranch
# 60627                            traditional
# 97370                               bungalow
# 2323                                   ranch
#
#        ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 32045                                    1.0     2023-10-26T00:00:00
# 64911                                    1.0     2024-01-08T00:00:00
# 60627                                    2.0     2024-02-02T00:00:00
# 97370                                    1.0     2024-05-29T00:00:00
# 2323                                     1.0     2023-11-21T00:00:00
#
#       Listing.ListingId  Listing.Price.ClosePrice  ... reverse cycle_cooling  \
# 32045       mrd11852720                  138000.0  ...                     0
# 64911       mrd11938750                  290000.0  ...                     0
# 60627       mrd11927754                  325000.0  ...                     0
# 97370       mrd12024781                  300000.0  ...                     0
# 2323        mrd11728531                  312212.0  ...                     0
#
#       roof turbine(s)_cooling space pac_cooling total_cooling  \
# 32045                       0                 0             0
# 64911                       0                 0             0
# 60627                       0                 0             0
# 97370                       0                 0             0
# 2323                        0                 0             0
#
#       wall sleeve_cooling window unit(s)_cooling window/wall unit - 1_cooling  \
# 32045                   0                      0                            0
# 64911                   0                      0                            0
# 60627                   0                      0                            0
# 97370                   0                      0                            0
# 2323                    0                      0                            0
#
#       window/wall units - 2_cooling window/wall units - 3+_cooling  \
# 32045                             0                              0
# 64911                             0                              0
# 60627                             0                              0
# 97370                             0                              0
# 2323                              0                              0
#
#        zoned_cooling
# 32045              0
# 64911              0
# 60627              0
# 97370              0
# 2323               0
#
# [5 rows x 420 columns]

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import spearmanr

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales
# Si hay valores NaN, los reemplazamos con ['Unknown']
train['ImageData.room_type_reso.results'] = train['ImageData.room_type_reso.results'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer para transformar las listas en variables binarias
mlb = MultiLabelBinarizer()
binary_features = mlb.fit_transform(train['ImageData.room_type_reso.results'])
binary_df = pd.DataFrame(binary_features, columns=mlb.classes_, index=train.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame original
binary_df.columns = [col + '_room' for col in binary_df.columns]

df = pd.concat([train, binary_df], axis=1)

# Paso 4: Realizar ANOVA para cada variable binarizada
anova_results = {}
for column in binary_df.columns:
    # Dividir la variable continua en grupos según la variable binaria
    group_0 = df[df[column] == 0]['Listing.Price.ClosePrice']
    group_1 = df[df[column] == 1]['Listing.Price.ClosePrice']
    
    # Calcular ANOVA
    if len(group_0) > 1 and len(group_1) > 1:  # Asegurarse de que hay suficientes datos en ambos grupos
        f_stat, p_value = f_oneway(group_0, group_1)
        anova_results[column] = (f_stat, p_value)
    else:
        anova_results[column] = (None, None)  # Insuficientes datos para el ANOVA

# Paso 5: Ordenar los resultados por el estadístico F
sorted_anova = sorted(anova_results.items(), key=lambda x: x[1][0] if x[1][0] is not None else 0, reverse=True)

# Paso 6: Filtrar características importantes según p-valor
threshold_p_value = 0.05
important_features = [feature for feature, (f_stat, p_value) in anova_results.items() if p_value is not None and p_value < threshold_p_value]

# Mostrar resultados
print("Resultados de ANOVA ordenados (por estadístico F):")
for feature, (f_stat, p_value) in sorted_anova:
    if f_stat is not None:
        print(f"{feature}: Estadístico F={f_stat:.3f}, p-valor={p_value:.3f}")

print("\nCaracterísticas importantes (p-valor < 0.05):", important_features)


significant_binary_df = binary_df[important_features]
train = pd.concat([train, significant_binary_df], axis=1)
# Out:
# Resultados de ANOVA ordenados (por estadístico F):
# DiningArea_room: Estadístico F=2657.804, p-valor=0.000
# Bar_room: Estadístico F=2399.485, p-valor=0.000
# FloorPlan_room: Estadístico F=2372.253, p-valor=0.000
# Patio_room: Estadístico F=2290.901, p-valor=0.000
# Office_room: Estadístico F=2273.603, p-valor=0.000
# MudRoom_room: Estadístico F=2145.328, p-valor=0.000
# WineCellar_room: Estadístico F=1691.565, p-valor=0.000
# ExerciseRoom_room: Estadístico F=1393.427, p-valor=0.000
# LivingRoom_room: Estadístico F=1367.187, p-valor=0.000
# GameRoom_room: Estadístico F=1337.106, p-valor=0.000
# EntranceFoyer_room: Estadístico F=975.302, p-valor=0.000
# MediaRoom_room: Estadístico F=933.523, p-valor=0.000
# Stairs_room: Estadístico F=889.516, p-valor=0.000
# WalkInClosets_room: Estadístico F=771.168, p-valor=0.000
# AerialView_room: Estadístico F=763.306, p-valor=0.000
# SittingRoom_room: Estadístico F=672.304, p-valor=0.000
# Deck_room: Estadístico F=619.940, p-valor=0.000
# Bedroom_room: Estadístico F=479.373, p-valor=0.000
# SunRoom_room: Estadístico F=433.883, p-valor=0.000
# SideOfStructure_room: Estadístico F=377.350, p-valor=0.000
# Sauna_room: Estadístico F=337.567, p-valor=0.000
# UtilityRoom_room: Estadístico F=322.688, p-valor=0.000
# Hallway_room: Estadístico F=319.941, p-valor=0.000
# Garage_room: Estadístico F=267.711, p-valor=0.000
# View_room: Estadístico F=248.438, p-valor=0.000
# Other_room: Estadístico F=235.082, p-valor=0.000
# Pool_room: Estadístico F=224.190, p-valor=0.000
# Gym_room: Estadístico F=199.648, p-valor=0.000
# Laundry_room: Estadístico F=163.188, p-valor=0.000
# Pantry_room: Estadístico F=151.455, p-valor=0.000
# Balcony_room: Estadístico F=149.541, p-valor=0.000
# Lobby_room: Estadístico F=138.632, p-valor=0.000
# OutBuildings_room: Estadístico F=135.414, p-valor=0.000
# Entry_room: Estadístico F=131.464, p-valor=0.000
# Basement_room: Estadístico F=119.022, p-valor=0.000
# BasketballCourt_room: Estadístico F=84.099, p-valor=0.000
# Map_room: Estadístico F=72.045, p-valor=0.000
# BonusRoom_room: Estadístico F=55.234, p-valor=0.000
# FrontOfStructure_room: Estadístico F=39.606, p-valor=0.000
# Closet_room: Estadístico F=31.501, p-valor=0.000
# Stable_room: Estadístico F=29.974, p-valor=0.000
# Fence_room: Estadístico F=22.005, p-valor=0.000
# Community_room: Estadístico F=21.355, p-valor=0.000
# Dock_room: Estadístico F=17.045, p-valor=0.000
# Attic_room: Estadístico F=13.091, p-valor=0.000
# Storage_room: Estadístico F=12.533, p-valor=0.000
# Parking_room: Estadístico F=11.904, p-valor=0.001
# BackOfStructure_room: Estadístico F=6.327, p-valor=0.012
# Bathroom_room: Estadístico F=5.094, p-valor=0.024
# Reception_room: Estadístico F=2.503, p-valor=0.114
# TennisCourt_room: Estadístico F=2.453, p-valor=0.117
# Yard_room: Estadístico F=2.126, p-valor=0.145
# Unknown_room: Estadístico F=0.785, p-valor=0.376
# Kitchen_room: Estadístico F=0.501, p-valor=0.479
# Playground_room: Estadístico F=0.115, p-valor=0.734
#
# Características importantes (p-valor < 0.05): ['AerialView_room', 'Attic_room', 'BackOfStructure_room', 'Balcony_room', 'Bar_room', 'Basement_room', 'BasketballCourt_room', 'Bathroom_room', 'Bedroom_room', 'BonusRoom_room', 'Closet_room', 'Community_room', 'Deck_room', 'DiningArea_room', 'Dock_room', 'EntranceFoyer_room', 'Entry_room', 'ExerciseRoom_room', 'Fence_room', 'FloorPlan_room', 'FrontOfStructure_room', 'GameRoom_room', 'Garage_room', 'Gym_room', 'Hallway_room', 'Laundry_room', 'LivingRoom_room', 'Lobby_room', 'Map_room', 'MediaRoom_room', 'MudRoom_room', 'Office_room', 'Other_room', 'OutBuildings_room', 'Pantry_room', 'Parking_room', 'Patio_room', 'Pool_room', 'Sauna_room', 'SideOfStructure_room', 'SittingRoom_room', 'Stable_room', 'Stairs_room', 'Storage_room', 'SunRoom_room', 'UtilityRoom_room', 'View_room', 'WalkInClosets_room', 'WineCellar_room']

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales en el conjunto de validación
valid['ImageData.room_type_reso.results'] = valid['ImageData.room_type_reso.results'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer entrenado con el conjunto de entrenamiento
# Usamos el `mlb` entrenado previamente en el conjunto de `train`
binary_features_valid = mlb.transform(valid['ImageData.room_type_reso.results'])
binary_df_valid = pd.DataFrame(binary_features_valid, columns=mlb.classes_, index=valid.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame de validación
binary_df_valid.columns = [col + '_room' for col in binary_df_valid.columns]
valid = pd.concat([valid, binary_df_valid], axis=1)

# Mostrar el DataFrame actualizado de validación con las nuevas características binarias
print(valid.head())
# Out:
#                           Characteristics.LotFeatures  \
# 32045                                       [Unknown]
# 64911                                       [Unknown]
# 60627  [pond(s), water view, sidewalks, streetlights]
# 97370                                       [Unknown]
# 2323                                        [Unknown]
#
#        ImageData.c1c6.summary.exterior  \
# 32045                          3.06213
# 64911                          3.50000
# 60627                          3.00000
# 97370                          4.00000
# 2323                           1.00000
#
#                          ImageData.features_reso.results  \
# 32045  [Appliances.Dishwasher, Appliances.ElectricRan...
# 64911  [Appliances.GasRange, Appliances.Range, Applia...
# 60627  [Appliances.Dishwasher, Appliances.GasRange, A...
# 97370  [Appliances.Dishwasher, Appliances.Refrigerato...
# 2323   [Appliances.Dishwasher, Appliances.Microwave, ...
#
#        ImageData.q1q6.summary.exterior  \
# 32045                         3.295942
# 64911                         4.200000
# 60627                         3.700000
# 97370                         3.900000
# 2323                          3.600000
#
#                         ImageData.room_type_reso.results  \
# 32045  [Bathroom, Kitchen, Other, Hallway, LivingRoom...
# 64911  [FrontOfStructure, Other, Bedroom, Kitchen, Ya...
# 60627  [FrontOfStructure, Other, Entry, Kitchen, Bath...
# 97370  [FrontOfStructure, LivingRoom, Kitchen, Dining...
# 2323   [FrontOfStructure, EntranceFoyer, Other, Kitch...
#
#       ImageData.style.exterior.summary.label  \
# 32045                                Unknown
# 64911                                  ranch
# 60627                            traditional
# 97370                               bungalow
# 2323                                   ranch
#
#        ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 32045                                    1.0     2023-10-26T00:00:00
# 64911                                    1.0     2024-01-08T00:00:00
# 60627                                    2.0     2024-02-02T00:00:00
# 97370                                    1.0     2024-05-29T00:00:00
# 2323                                     1.0     2023-11-21T00:00:00
#
#       Listing.ListingId  Listing.Price.ClosePrice  ... Stairs_room  \
# 32045       mrd11852720                  138000.0  ...           0
# 64911       mrd11938750                  290000.0  ...           0
# 60627       mrd11927754                  325000.0  ...           0
# 97370       mrd12024781                  300000.0  ...           0
# 2323        mrd11728531                  312212.0  ...           0
#
#       Storage_room SunRoom_room TennisCourt_room Unknown_room  \
# 32045            1            0                0            0
# 64911            0            0                0            0
# 60627            0            0                0            0
# 97370            0            0                0            0
# 2323             0            0                0            0
#
#       UtilityRoom_room View_room WalkInClosets_room WineCellar_room  Yard_room
# 32045                0         1                  0               0          0
# 64911                0         0                  0               0          1
# 60627                0         0                  0               0          1
# 97370                0         0                  0               0          1
# 2323                 0         0                  1               0          0
#
# [5 rows x 475 columns]

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import spearmanr

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales
# Si hay valores NaN, los reemplazamos con ['Unknown']
train['Structure.Heating'] = train['Structure.Heating'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer para transformar las listas en variables binarias
mlb = MultiLabelBinarizer()
binary_features = mlb.fit_transform(train['Structure.Heating'])
binary_df = pd.DataFrame(binary_features, columns=mlb.classes_, index=train.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame original
binary_df.columns = [col + '_heating' for col in binary_df.columns]
df = pd.concat([train, binary_df], axis=1)

# Paso 4: Realizar ANOVA para cada variable binarizada
anova_results = {}
for column in binary_df.columns:
    # Dividir la variable continua en grupos según la variable binaria
    group_0 = df[df[column] == 0]['Listing.Price.ClosePrice']
    group_1 = df[df[column] == 1]['Listing.Price.ClosePrice']
    
    # Calcular ANOVA
    if len(group_0) > 1 and len(group_1) > 1:  # Asegurarse de que hay suficientes datos en ambos grupos
        f_stat, p_value = f_oneway(group_0, group_1)
        anova_results[column] = (f_stat, p_value)
    else:
        anova_results[column] = (None, None)  # Insuficientes datos para el ANOVA

# Paso 5: Ordenar los resultados por el estadístico F
sorted_anova = sorted(anova_results.items(), key=lambda x: x[1][0] if x[1][0] is not None else 0, reverse=True)

# Paso 6: Filtrar características importantes según p-valor
threshold_p_value = 0.05
important_features = [feature for feature, (f_stat, p_value) in anova_results.items() if p_value is not None and p_value < threshold_p_value]

# Mostrar resultados
print("Resultados de ANOVA ordenados (por estadístico F):")
for feature, (f_stat, p_value) in sorted_anova:
    if f_stat is not None:
        print(f"{feature}: Estadístico F={f_stat:.3f}, p-valor={p_value:.3f}")

print("\nCaracterísticas importantes (p-valor < 0.05):", important_features)

significant_binary_df = binary_df[important_features]
train = pd.concat([train, significant_binary_df], axis=1)
# Out:
# Resultados de ANOVA ordenados (por estadístico F):
# zoned_heating: Estadístico F=6192.548, p-valor=0.000
# sep heating systems - 2+_heating: Estadístico F=3037.015, p-valor=0.000
# radiant_heating: Estadístico F=799.974, p-valor=0.000
# indv controls_heating: Estadístico F=690.720, p-valor=0.000
# Unknown_heating: Estadístico F=452.416, p-valor=0.000
# forced air_heating: Estadístico F=229.524, p-valor=0.000
# electric_heating: Estadístico F=145.744, p-valor=0.000
# natural gas_heating: Estadístico F=117.996, p-valor=0.000
# baseboard_heating: Estadístico F=117.567, p-valor=0.000
# heat pump_heating: Estadístico F=113.167, p-valor=0.000
# geothermal_heating: Estadístico F=59.991, p-valor=0.000
# radiator(s)_heating: Estadístico F=59.379, p-valor=0.000
# none_heating: Estadístico F=47.579, p-valor=0.000
# solar_heating: Estadístico F=32.651, p-valor=0.000
# other_heating: Estadístico F=30.456, p-valor=0.000
# propane_heating: Estadístico F=21.472, p-valor=0.000
# floor furnace_heating: Estadístico F=10.483, p-valor=0.001
# space heater_heating: Estadístico F=4.176, p-valor=0.041
# wood_heating: Estadístico F=3.959, p-valor=0.047
# steam_heating: Estadístico F=3.875, p-valor=0.049
# oil_heating: Estadístico F=0.888, p-valor=0.346
# gravity air_heating: Estadístico F=0.400, p-valor=0.527
#
# Características importantes (p-valor < 0.05): ['Unknown_heating', 'baseboard_heating', 'electric_heating', 'floor furnace_heating', 'forced air_heating', 'geothermal_heating', 'heat pump_heating', 'indv controls_heating', 'natural gas_heating', 'none_heating', 'other_heating', 'propane_heating', 'radiant_heating', 'radiator(s)_heating', 'sep heating systems - 2+_heating', 'solar_heating', 'space heater_heating', 'steam_heating', 'wood_heating', 'zoned_heating']

# %%
import pandas as pd
import ast  # Para convertir cadenas en listas
from sklearn.preprocessing import MultiLabelBinarizer

# Paso 1: Manejar valores NaN y convertir cadenas en listas reales en el conjunto de validación
valid['Structure.Heating'] = valid['Structure.Heating'].apply(
    lambda x: ['Unknown'] if pd.isna(x) else (ast.literal_eval(x) if isinstance(x, str) else x)
)

# Paso 2: Aplicar MultiLabelBinarizer entrenado con el conjunto de entrenamiento
# Usamos el `mlb` entrenado previamente en el conjunto de `train`
binary_features_valid = mlb.transform(valid['Structure.Heating'])
binary_df_valid = pd.DataFrame(binary_features_valid, columns=mlb.classes_, index=valid.index)

# Paso 3: Concatenar las columnas binarias con el DataFrame de validación
binary_df_valid.columns = [col + '_heating' for col in binary_df_valid.columns]
valid = pd.concat([valid, binary_df_valid], axis=1)

# Mostrar el DataFrame actualizado de validación con las nuevas características binarias
print(valid.head())
# Out:
#                           Characteristics.LotFeatures  \
# 32045                                       [Unknown]
# 64911                                       [Unknown]
# 60627  [pond(s), water view, sidewalks, streetlights]
# 97370                                       [Unknown]
# 2323                                        [Unknown]
#
#        ImageData.c1c6.summary.exterior  \
# 32045                          3.06213
# 64911                          3.50000
# 60627                          3.00000
# 97370                          4.00000
# 2323                           1.00000
#
#                          ImageData.features_reso.results  \
# 32045  [Appliances.Dishwasher, Appliances.ElectricRan...
# 64911  [Appliances.GasRange, Appliances.Range, Applia...
# 60627  [Appliances.Dishwasher, Appliances.GasRange, A...
# 97370  [Appliances.Dishwasher, Appliances.Refrigerato...
# 2323   [Appliances.Dishwasher, Appliances.Microwave, ...
#
#        ImageData.q1q6.summary.exterior  \
# 32045                         3.295942
# 64911                         4.200000
# 60627                         3.700000
# 97370                         3.900000
# 2323                          3.600000
#
#                         ImageData.room_type_reso.results  \
# 32045  [Bathroom, Kitchen, Other, Hallway, LivingRoom...
# 64911  [FrontOfStructure, Other, Bedroom, Kitchen, Ya...
# 60627  [FrontOfStructure, Other, Entry, Kitchen, Bath...
# 97370  [FrontOfStructure, LivingRoom, Kitchen, Dining...
# 2323   [FrontOfStructure, EntranceFoyer, Other, Kitch...
#
#       ImageData.style.exterior.summary.label  \
# 32045                                Unknown
# 64911                                  ranch
# 60627                            traditional
# 97370                               bungalow
# 2323                                   ranch
#
#        ImageData.style.stories.summary.label Listing.Dates.CloseDate  \
# 32045                                    1.0     2023-10-26T00:00:00
# 64911                                    1.0     2024-01-08T00:00:00
# 60627                                    2.0     2024-02-02T00:00:00
# 97370                                    1.0     2024-05-29T00:00:00
# 2323                                     1.0     2023-11-21T00:00:00
#
#       Listing.ListingId  Listing.Price.ClosePrice  ... other_heating  \
# 32045       mrd11852720                  138000.0  ...             0
# 64911       mrd11938750                  290000.0  ...             0
# 60627       mrd11927754                  325000.0  ...             0
# 97370       mrd12024781                  300000.0  ...             0
# 2323        mrd11728531                  312212.0  ...             0
#
#       propane_heating radiant_heating radiator(s)_heating  \
# 32045               0               0                   0
# 64911               0               0                   0
# 60627               0               0                   0
# 97370               0               0                   0
# 2323                0               0                   0
#
#       sep heating systems - 2+_heating solar_heating space heater_heating  \
# 32045                                0             0                    0
# 64911                                0             0                    0
# 60627                                0             0                    0
# 97370                                0             0                    0
# 2323                                 0             0                    0
#
#       steam_heating wood_heating  zoned_heating
# 32045             0            0              0
# 64911             0            0              0
# 60627             0            0              0
# 97370             0            0              0
# 2323              0            0              0
#
# [5 rows x 498 columns]

# %%
#Mirar los valores missings de la base de datos
missing_values = train.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
missing_values = valid.isnull().sum()
missing_values_percent = missing_values / len(train) * 100
missing_values_table = pd.concat([missing_values, missing_values_percent], axis=1)
missing_values_table.columns = ["Missing Values", "Percentage"]
missing_values_table = missing_values_table[missing_values_table["Missing Values"] > 0]
missing_values_table = missing_values_table.sort_values(by="Missing Values", ascending=False)
print(missing_values_table)
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
# Guardem el dataset de train
train.to_csv('train_cleaned.csv', index=False)

# %%
valid.to_csv('valid_cleaned.csv', index=False)
